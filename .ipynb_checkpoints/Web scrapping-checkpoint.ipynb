# %%
import requests
import pandas as pd

# %% [markdown]
# ## Pobieranie wyników turnieju- część 1

# %%
def scores_pipeline(url):
    pd.read_html(requests.get(url).content)[-1].to_csv("mydata.csv")
    df=pd.read_csv('mydata.csv')
    df=df.drop(['Unnamed: 0','+/-','pkl', 'pdf'],axis=1)
    return df

# %%
def regex_trans_scores(df):
    import re
    pierwszy=[]
    drugi=[]
    for i in range(len(df)):
        pierwszy.append(re.findall('[A-ZŻŹĆĄŚĘŁÓŃ][^A-ZŻŹĆĄŚĘŁÓŃ]*', df.nazwiska[i])[0]+re.findall('[A-ZŻŹĆĄŚĘŁÓŃ][^A-ZŻŹĆĄŚĘŁÓŃ]*', df.nazwiska[i])[1])
        drugi.append(re.findall('[A-ZŻŹĆĄŚĘŁÓŃ][^A-ZŻŹĆĄŚĘŁÓŃ]*', df.nazwiska[i])[2]+re.findall('[A-ZŻŹĆĄŚĘŁÓŃ][^A-ZŻŹĆĄŚĘŁÓŃ]*', df.nazwiska[i])[3])
    df['nazwisko_1']=pierwszy
    df['nazwisko_2']=drugi
    df=df.drop('nazwiska',axis=1)


    wk1=[]
    wk2=[]
    for i in range(len(df)):
        wk1.append(re.findall("\d+\.\d", df.wk[i])[0])
        wk2.append(re.findall("\d+\.\d", df.wk[i])[1])
    df['wk_1']=wk1
    df['wk_2']=wk2
    df=df.drop(['wk','ośrodek','okręg'],axis=1)
    return df

# %% [markdown]
# ## Pobieranie wyników poszczególnych rozdań

# %%
def get_hist(n,vector):
    pd.read_html(requests.get(f"https://r.bridgespider.com/{vector[0]}/prot/{1}/").content)[-1].to_csv("mydat.csv")
    tmp=pd.read_csv('mydat.csv')
    tmp['nr_rozdania']=1
    tmp['nr_turnieju']=vector[0]
    for j in range (len(vector)):
        for i in range(1,n):
            pd.read_html(requests.get(f"https://r.bridgespider.com/{vector[j]}/prot/{i+1}/").content)[-1].to_csv("mydat.csv")
            zz=pd.read_csv('mydat.csv')
            zz['nr_rozdania']=i+1
            zz['nr_turnieju']=vector[j]
            tmp=pd.concat([tmp,zz])
    return tmp

# %%
tmp=pd.read_html(requests.get(f"https://r.bridgespider.com/{25890}/prot/{1}/").content)[-1].to_csv("mydat.csv")

# %%
tmp=pd.read_csv('mydat.csv')

# %%
pd.concat([tmp,tmp])
# Out:
#      Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
# 0             0  DS/136      5    8   11        2     E    8  +1   -150
# 1             1  DS/136      3    5    9        1     W    5  +3   -180
# 2             2  DS/136      6   10    7        2     E    3  +2   -180
# 3             3  DS/136      4    3    2        3     E    3   =   -400
# 4             4  DS/136      9    4    6        3     E    8   =   -400
# ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
# 248         248  ZP/452     11  530  532        3     E    3  -2    100
# 249         249  ZP/452     12  525  528        3     E    6   =   -400
# 250         250  ZP/452     13  527  523        3     W    5   =   -400
# 251         251  ZP/452     14  529  522        3     W    5  +1   -430
# 252         252  ZP/452     15  533  524        3     E    6   =   -400
#
#       % NS   % EW  Unnamed: 11
# 0    67.46  32.54          NaN
# 1    57.74  42.26          NaN
# 2    57.74  42.26          NaN
# 3    38.89  61.11          NaN
# 4    38.89  61.11          NaN
# ..     ...    ...          ...
# 248  98.61   1.39          NaN
# 249  38.89  61.11          NaN
# 250  38.89  61.11          NaN
# 251  13.29  86.71          NaN
# 252  38.89  61.11          NaN
#
# [506 rows x 13 columns]

# %%
def pipeline(df2):
    df2=df2.drop(['Unnamed: 0','ośrodek','runda','wist','Unnamed: 11','lew','kontrakt'],axis=1)
    df2['rozg.']=df2['rozg.'].replace(['E','W'],'EW')
    df2['rozg.']=df2['rozg.'].replace(['N','S'],'NS')
    df2['zapis_NS']=df2['zapis']
    df2['zapis_EW']=df2['zapis']*(-1)
    df2=df2.drop('zapis',axis=1)
    return df2

# %%
def pipeline2(df_x):
    tmp1=df_x.copy()
    tmp2=df_x.copy()
    tmp1=tmp1.drop(['EW','% EW','zapis_EW'],axis=1)
    tmp1['linia']='NS'
    tmp2=tmp2.drop(['NS','% NS','zapis_NS'],axis=1)
    tmp2['linia']='EW'
    tmp1.columns=['id','rozg','wynik','nr_rozdania','nr_turnieju','zapis','linia']
    tmp2.columns=['id','rozg','wynik','nr_rozdania','nr_turnieju','zapis','linia']
    tmp=pd.concat([tmp1,tmp2])
    return tmp

# %%
def refactor(history):
    history=pipeline(history)
    history=pipeline2(history)
    return history

# %% [markdown]
# ## Main

# %%
scores=scores_pipeline("https://r.bridgespider.com/25890/")
scores=regex_trans_scores(scores)
scores['nr_turnieju']=25890
scores
# Out:
#      m-ce   nr      %             nazwisko_1          nazwisko_2 wk_1  wk_2  \
# 0       1   99  66.18             Jerzy Pala      Jan Styczyński  5.0   5.0
# 1       2  140  65.97       Sebastian Rawlik      Damian Mazurak  5.0   5.0
# 2       3   10  64.60     Janusz Czerniawski    Zbigniew Buciuto  5.0   3.0
# 3       4  527  64.47         Ryszard Smejda      Damian Wroński  7.0  11.0
# 4       5  247  64.31         Wojciech Słysz   Marek Melsztyński  1.5   2.0
# ..    ...  ...    ...                    ...                 ...  ...   ...
# 517   518  271  33.67          Jerzy Słomski  Jolanta Wiśniewska  2.5   4.0
# 518   519  356  32.97       Leszek Zieliński     Janusz Bakalarz  4.0   0.5
# 519   520  361  31.28     Natalia Fręchowicz           Jan Luber  0.0   0.0
# 520   521  109  31.06      Wincenty Tęgowski    Paweł Jankiewicz  0.0   0.0
# 521   522  249  24.82  Małgorzata Skowrońska     Matylda Brzyzka  0.0   0.0
#
#      nr_turnieju
# 0          25890
# 1          25890
# 2          25890
# 3          25890
# 4          25890
# ..           ...
# 517        25890
# 518        25890
# 519        25890
# 520        25890
# 521        25890
#
# [522 rows x 8 columns]

# %%
history=get_hist(30)
history=refactor(history)
history[0]
# Out:
#       id rozg  wynik  zapis linia
# 0      8   EW  67.46   -150    NS
# 1      5   EW  57.74   -180    NS
# 2     10   EW  57.74   -180    NS
# 3      3   EW  38.89   -400    NS
# 4      4   EW  38.89   -400    NS
# ..   ...  ...    ...    ...   ...
# 248  532   EW   1.39   -100    EW
# 249  528   EW  61.11    400    EW
# 250  523   EW  61.11    400    EW
# 251  522   EW  86.71    430    EW
# 252  524   EW  61.11    400    EW
#
# [506 rows x 5 columns]

# %% [markdown]
# ## Część 2

# %%
for i in range(30):
    history[i]['numer_rozdania']=i+1

# %%
tmp=pd.concat([history[0],history[1]])
for i in range(2,len(history)):
    tmp=pd.concat([tmp,history[i]])
tmp
# Out:
#       id rozg  wynik  zapis linia  numer_rozdania
# 0      8   EW  67.46 -150.0    NS               1
# 1      5   EW  57.74 -180.0    NS               1
# 2     10   EW  57.74 -180.0    NS               1
# 3      3   EW  38.89 -400.0    NS               1
# 4      4   EW  38.89 -400.0    NS               1
# ..   ...  ...    ...    ...   ...             ...
# 136  531   EW  78.84  170.0    EW              30
# 137  527   EW  78.84  170.0    EW              30
# 138  522   EW  78.84  170.0    EW              30
# 139  521   EW  56.41  140.0    EW              30
# 140  523   EW  78.84  170.0    EW              30
#
# [14596 rows x 6 columns]

# %%
tmp1=tmp[tmp['rozg']==tmp['linia']]
tmp2=tmp[tmp['rozg']!=tmp['linia']]
tmp1['czy_rozgrywa']=True
tmp2['czy_rozgrywa']=False
tmp=pd.concat([tmp1,tmp2])
# Out:
# C:\Users\p.okonek\AppData\Local\Temp\ipykernel_15768\3798423981.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp1['czy_rozgrywa']=True
# C:\Users\p.okonek\AppData\Local\Temp\ipykernel_15768\3798423981.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp2['czy_rozgrywa']=False

# %%
tmp[tmp['id']==99].reset_index()
# Out:
#     index  id rozg  wynik   zapis linia  numer_rozdania  czy_rozgrywa
# 0      47  99   EW  61.11   400.0    EW               1          True
# 1      47  99   EW  89.00  1010.0    EW               2          True
# 2      51  99   NS  69.48   650.0    NS               4          True
# 3      51  99   NS  58.53   140.0    NS               5          True
# 4      51  99   NS  82.74   460.0    NS               6          True
# 5      51  99   EW  98.40   590.0    EW               8          True
# 6      48  99   NS  54.96   140.0    NS              11          True
# 7      52  99   EW  96.63   170.0    EW              16          True
# 8      52  99   EW  88.25  -100.0    EW              18          True
# 9      50  99   NS  24.70   180.0    NS              21          True
# 10     47  99   NS  97.54   110.0    NS              27          True
# 11     50  99   EW  33.27  -100.0    EW              28          True
# 12     46  99   EW  55.34   600.0    EW              29          True
# 13     46  99   EW  98.06   420.0    EW              30          True
# 14     47  99   NS  75.20   100.0    EW               3         False
# 15     51  99   NS  80.16   200.0    EW               7         False
# 16     51  99   NS  56.18  -110.0    EW               9         False
# 17     48  99   EW  46.63  -630.0    NS              10         False
# 18     48  99   EW  46.41  -400.0    NS              12         False
# 19     52  99   NS  75.70   -90.0    EW              17         False
# 20     50  99   EW  93.87   300.0    NS              19         False
# 21     50  99   EW  95.04   200.0    NS              20         False
# 22     49  99   EW  91.11   100.0    NS              22         False
# 23     49  99   EW  14.03  -140.0    NS              23         False
# 24     49  99   EW  59.29    50.0    NS              24         False
# 25     47  99   EW  12.10  -650.0    NS              25         False
# 26     47  99   EW  33.07  -110.0    NS              26         False

# %%
tab=[25845,25809,25773,25737,25692,24384,24339,24303,24267,24222,24186,24150,22079 ,22043 ,21800,21764,21728,17693,17666]

# %%
url="https://r.bridgespider.com/"

# %%
url+str(tab[2])+'/'
# Out:
# 'https://r.bridgespider.com/25773/'

# %%
scores
# Out:
#      m-ce   nr      %             nazwisko_1          nazwisko_2 wk_1  wk_2  \
# 0       1   99  66.18             Jerzy Pala      Jan Styczyński  5.0   5.0
# 1       2  140  65.97       Sebastian Rawlik      Damian Mazurak  5.0   5.0
# 2       3   10  64.60     Janusz Czerniawski    Zbigniew Buciuto  5.0   3.0
# 3       4  527  64.47         Ryszard Smejda      Damian Wroński  7.0  11.0
# 4       5  247  64.31         Wojciech Słysz   Marek Melsztyński  1.5   2.0
# ..    ...  ...    ...                    ...                 ...  ...   ...
# 517   518  271  33.67          Jerzy Słomski  Jolanta Wiśniewska  2.5   4.0
# 518   519  356  32.97       Leszek Zieliński     Janusz Bakalarz  4.0   0.5
# 519   520  361  31.28     Natalia Fręchowicz           Jan Luber  0.0   0.0
# 520   521  109  31.06      Wincenty Tęgowski    Paweł Jankiewicz  0.0   0.0
# 521   522  249  24.82  Małgorzata Skowrońska     Matylda Brzyzka  0.0   0.0
#
#      nr_turnieju
# 0          25890
# 1          25890
# 2          25890
# 3          25890
# 4          25890
# ..           ...
# 517        25890
# 518        25890
# 519        25890
# 520        25890
# 521        25890
#
# [522 rows x 8 columns]

# %% [markdown]
# -------------------------------

# %%
for i in tab:
    url="https://r.bridgespider.com/"
    url=url+str(i)+'/'
    tmp=scores_pipeline(url)
    tmp=regex_trans_scores(tmp)
    tmp['nr_turnieju']=i
    scores=pd.concat([tmp,scores])
    
scores
# Out:
#      m-ce   nr      %             nazwisko_1            nazwisko_2  wk_1  \
# 0       1  660  67.09          Grażyna Busse           Piotr Busse  15.0
# 1       2  597  65.96        Jerzy Ratkowski           Jerzy Sukow   5.0
# 2       3  374  65.35      Dariusz Krakowiak            Jacek Lech   3.0
# 3       4  720  64.69     Władysław Tomasiak  Wojciech Bondarewicz  13.0
# 4       5   33  64.43       Jarosław Kowalik       Roman Wyszowski   5.0
# ..    ...  ...    ...                    ...                   ...   ...
# 517   518  271  33.67          Jerzy Słomski    Jolanta Wiśniewska   2.5
# 518   519  356  32.97       Leszek Zieliński       Janusz Bakalarz   4.0
# 519   520  361  31.28     Natalia Fręchowicz             Jan Luber   0.0
# 520   521  109  31.06      Wincenty Tęgowski      Paweł Jankiewicz   0.0
# 521   522  249  24.82  Małgorzata Skowrońska       Matylda Brzyzka   0.0
#
#      wk_2  nr_turnieju
# 0    19.0        17666
# 1    12.0        17666
# 2     2.0        17666
# 3     4.0        17666
# 4     5.0        17666
# ..    ...          ...
# 517   4.0        25890
# 518   0.5        25890
# 519   0.0        25890
# 520   0.0        25890
# 521   0.0        25890
#
# [9718 rows x 8 columns]

# %%
scores['unique_id'] = scores.groupby(['nazwisko_1', 'nazwisko_2']).ngroup()
scores
# Out:
#      m-ce   nr      %             nazwisko_1            nazwisko_2  wk_1  \
# 0       1  660  67.09          Grażyna Busse           Piotr Busse  15.0
# 1       2  597  65.96        Jerzy Ratkowski           Jerzy Sukow   5.0
# 2       3  374  65.35      Dariusz Krakowiak            Jacek Lech   3.0
# 3       4  720  64.69     Władysław Tomasiak  Wojciech Bondarewicz  13.0
# 4       5   33  64.43       Jarosław Kowalik       Roman Wyszowski   5.0
# ..    ...  ...    ...                    ...                   ...   ...
# 517   518  271  33.67          Jerzy Słomski    Jolanta Wiśniewska   2.5
# 518   519  356  32.97       Leszek Zieliński       Janusz Bakalarz   4.0
# 519   520  361  31.28     Natalia Fręchowicz             Jan Luber   0.0
# 520   521  109  31.06      Wincenty Tęgowski      Paweł Jankiewicz   0.0
# 521   522  249  24.82  Małgorzata Skowrońska       Matylda Brzyzka   0.0
#
#      wk_2  nr_turnieju  unique_id
# 0    19.0        17666       1199
# 1    12.0        17666       2029
# 2     2.0        17666        883
# 3     4.0        17666       4565
# 4     5.0        17666       1865
# ..    ...          ...        ...
# 517   4.0        25890       2078
# 518   0.5        25890       2591
# 519   0.0        25890       3234
# 520   0.0        25890       4430
# 521   0.0        25890       3052
#
# [9718 rows x 9 columns]

# %%
vector=scores["unique_id"].value_counts().index.tolist()[:10]

# %%
top10=scores.loc[scores["unique_id"].isin(vector)]

# %%
top10
# Out:
#      m-ce   nr      %           nazwisko_1          nazwisko_2 wk_1 wk_2  \
# 55     56  700  59.53          Rafał Junik     Jolanta Ziętara  7.0  5.0
# 148   149  592  55.67     Wiesław Pietrzak         Zenon Wawer  5.0  5.0
# 237   238  207  52.96    Krzysztof Borowik     Henryk Choiński  0.0  3.0
# 250   251  202  52.59  Franciszek Bułyszko   Zbigniew Józefiak  4.0  4.0
# 318   319   13  51.25  Andrzej Augustyniak        Henryk Gayny  5.0  2.0
# ..    ...  ...    ...                  ...                 ...  ...  ...
# 193   194  388  52.54     Wiesław Pietrzak         Zenon Wawer  5.0  5.0
# 285   286  198  49.09    Krzysztof Borowik     Henryk Choiński  1.5  3.0
# 405   406  200  44.91     Sławomir Rutecki     Tadeusz Birecki  7.0  5.0
# 441   442  199  43.00  Franciszek Bułyszko   Zbigniew Józefiak  4.0  5.0
# 458   459  386  41.79   Wiesława Nawojczyk  Andrzej Michalczyk  0.5  0.5
#
#      nr_turnieju  unique_id
# 55         17666       3473
# 148        17666       4382
# 237        17666       2359
# 250        17666       1158
# 318        17666        178
# ..           ...        ...
# 193        25890       4382
# 285        25890       2359
# 405        25890       3963
# 441        25890       1158
# 458        25890       4416
#
# [160 rows x 9 columns]

# %% [markdown]
# ## Zawodnicy z Cezara

# %%
url="https://msc.com.pl/cezar/?p=51&rok=0&page=1"

# %%
pd.read_html(requests.get(url).content)[-1].to_csv("mydata.csv")
df=pd.read_csv('mydata.csv')

# %%
tables = pd.read_html(url,match="klub / drużyna")
df=tables[2]

# %%
for i in range(65,337):
    url=f"https://msc.com.pl/cezar/?p=51&rok=0&page={i}"
    tables = pd.read_html(url,match="klub / drużyna")
    df=pd.concat([df,tables[2]])

# %%
df.to_csv('Lista_Zawodnikow.csv')

# %%
scores
# Out:
#      m-ce   nr      %             nazwisko_1            nazwisko_2  wk_1  \
# 0       1  660  67.09          Grażyna Busse           Piotr Busse  15.0
# 1       2  597  65.96        Jerzy Ratkowski           Jerzy Sukow   5.0
# 2       3  374  65.35      Dariusz Krakowiak            Jacek Lech   3.0
# 3       4  720  64.69     Władysław Tomasiak  Wojciech Bondarewicz  13.0
# 4       5   33  64.43       Jarosław Kowalik       Roman Wyszowski   5.0
# ..    ...  ...    ...                    ...                   ...   ...
# 517   518  271  33.67          Jerzy Słomski    Jolanta Wiśniewska   2.5
# 518   519  356  32.97       Leszek Zieliński       Janusz Bakalarz   4.0
# 519   520  361  31.28     Natalia Fręchowicz             Jan Luber   0.0
# 520   521  109  31.06      Wincenty Tęgowski      Paweł Jankiewicz   0.0
# 521   522  249  24.82  Małgorzata Skowrońska       Matylda Brzyzka   0.0
#
#      wk_2  nr_turnieju  unique_id
# 0    19.0        17666       1199
# 1    12.0        17666       2029
# 2     2.0        17666        883
# 3     4.0        17666       4565
# 4     5.0        17666       1865
# ..    ...          ...        ...
# 517   4.0        25890       2078
# 518   0.5        25890       2591
# 519   0.0        25890       3234
# 520   0.0        25890       4430
# 521   0.0        25890       3052
#
# [9718 rows x 9 columns]

# %%
scores.columns
# Out:
# Index(['m-ce', 'nr', '%', 'nazwisko_1', 'nazwisko_2', 'wk_1', 'wk_2',
#        'nr_turnieju', 'unique_id'],
#       dtype='object')

# %%
scores_1=scores[['m-ce', 'nr', '%', 'nazwisko_1','wk_1','nr_turnieju']]
scores_2=scores[['m-ce', 'nr', '%', 'nazwisko_2','wk_2','nr_turnieju']]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
scores_1['nazwisko']=scores_1['nazwisko_1']
scores_2['nazwisko']=scores_2['nazwisko_2']
scores_1['wk']=scores_1['wk_1']
scores_2['wk']=scores_2['wk_2']
scores_1=scores_1.drop(['nazwisko_1','wk_1'],axis=1)
scores_2=scores_2.drop(['nazwisko_2','wk_2'],axis=1)

# %%
scores_new=pd.concat([scores_1,scores_2])

# %%
df.rename(columns = {2: 'name'}, inplace = True)

# %%
df.rename(columns = {1: 'PID'}, inplace = True)

# %%
df
# Out:
#          0    PID                   name     3   4   5        6     7  \
# 0   lokata    PID        imię i nazwisko  WZBS  WK  TK      PKL  liga
# 1       1.  06706     Apolinary Kowalski    WM  24  AS  187 649     E
# 2       2.  08513           Piotr Gawryś    DS  24  AS  149 944     E
# 3       3.  06658           Jacek Kalita    SW  24  AS  146 928     E
# 4       4.  01221         Cezary Balicki    DS  24  AS  143 379     -
# ..     ...    ...                    ...   ...  ..  ..      ...   ...
# 46     NaN  20956            Maciej Wisz    PK   0   D        1     -
# 47     NaN  17464  Małgorzata Wiśniewska    DS   0   D        1     -
# 48     NaN  20096       Adrian Witkowski    KP   0   D        1     -
# 49     NaN  21716         Jakub Witowski    PK   0   D        1     -
# 50     NaN  20387     Hanna Witruszyńska    DS   0   D        1     -
#
#                                         8
# 0                          klub / drużyna
# 1                       VITAS ESBS Elblag
# 2   BRIDGESCANNER KS AZS Wratislavia I WR
# 3                 SPS CONSTRUCTION Kielce
# 4                                     NaN
# ..                                    ...
# 46                  Singleton Podkarpacki
# 47                                    NaN
# 48                                    NaN
# 49                  Singleton Podkarpacki
# 50                                    NaN
#
# [13923 rows x 9 columns]

# %%
last_scores=scores_new.merge(df[['PID','name']],left_on='nazwisko',right_on='name')

# %%
last_scores=last_scores.drop(['name'],axis=1)

# %%
last_scores
# Out:
#        m-ce   nr      %  nr_turnieju              nazwisko   wk    PID
# 0         3  374  65.35        17666     Dariusz Krakowiak  3.0  17854
# 1        33  384  61.43        17693     Dariusz Krakowiak  3.0  17854
# 2       183  366  55.17        21728     Dariusz Krakowiak  3.0  17854
# 3        49  384  60.59        21764     Dariusz Krakowiak  3.0  17854
# 4        72   52  46.54        24150     Dariusz Krakowiak  3.0  17854
# ...     ...  ...    ...          ...                   ...  ...    ...
# 11754   232  176  51.10        25890        Andrzej Piętak  3.0  08323
# 11755   303  455  48.75        25890       Andrzej Grześko  2.0  19403
# 11756   321   20  48.22        25890  Tymoteusz Zaborowski  1.5  17787
# 11757   467  411  40.96        25890    Wiesław Kulikowski  1.5  15109
# 11758   522  249  24.82        25890       Matylda Brzyzka  0.0  21471
#
# [11759 rows x 7 columns]

# %%
zz=last_scores[last_scores[['nr_turnieju','nazwisko']].duplicated(keep=False)]

# %%
last_scores=pd.concat([last_scores,zz]).drop_duplicates(keep=False)

# %%
tmp
# Out:
#      m-ce   nr      %           nazwisko_1            nazwisko_2  wk_1  wk_2  \
# 0       1  660  67.09        Grażyna Busse           Piotr Busse  15.0  19.0
# 1       2  597  65.96      Jerzy Ratkowski           Jerzy Sukow   5.0  12.0
# 2       3  374  65.35    Dariusz Krakowiak            Jacek Lech   3.0   2.0
# 3       4  720  64.69   Władysław Tomasiak  Wojciech Bondarewicz  13.0   4.0
# 4       5   33  64.43     Jarosław Kowalik       Roman Wyszowski   5.0   5.0
# ..    ...  ...    ...                  ...                   ...   ...   ...
# 747   748  459  34.16        Adam Maryniak        Bożena Materna   0.0   0.0
# 748   749   66  33.28      Jerzy Stypiński      Tadeusz Janeczek   3.0   3.0
# 749   750  431  33.07   Ireneusz Hebdowski       Jan Kurianowicz   0.0   0.0
# 750   751    5  31.37  Zbigniew Leśniewski    Mikołaj Piotrowski   1.5   0.0
# 751   752  698  29.60      Leszek Kłopocki       Tadeusz Osowski   0.0   0.5
#
#      nr_turnieju
# 0          17666
# 1          17666
# 2          17666
# 3          17666
# 4          17666
# ..           ...
# 747        17666
# 748        17666
# 749        17666
# 750        17666
# 751        17666
#
# [752 rows x 8 columns]

# %%
last_scores
# Out:
#        m-ce   nr      %  nr_turnieju              nazwisko   wk    PID
# 0         3  374  65.35        17666     Dariusz Krakowiak  3.0  17854
# 1        33  384  61.43        17693     Dariusz Krakowiak  3.0  17854
# 2       183  366  55.17        21728     Dariusz Krakowiak  3.0  17854
# 3        49  384  60.59        21764     Dariusz Krakowiak  3.0  17854
# 4        72   52  46.54        24150     Dariusz Krakowiak  3.0  17854
# ...     ...  ...    ...          ...                   ...  ...    ...
# 11754   232  176  51.10        25890        Andrzej Piętak  3.0  08323
# 11755   303  455  48.75        25890       Andrzej Grześko  2.0  19403
# 11756   321   20  48.22        25890  Tymoteusz Zaborowski  1.5  17787
# 11757   467  411  40.96        25890    Wiesław Kulikowski  1.5  15109
# 11758   522  249  24.82        25890       Matylda Brzyzka  0.0  21471
#
# [10441 rows x 7 columns]

# %%
last_scores['nazwisko'].value_counts()
# Out:
# Dariusz Krakowiak      20
# Zbigniew Bobak         20
# Przemysław Wojtczak    20
# Henryk Choiński        19
# Krzysztof Borowik      19
#                        ..
# Antoni Kierepka         1
# Marek Księżopolski      1
# Szymon Mazur            1
# Janusz Kurkowski        1
# Matylda Brzyzka         1
# Name: nazwisko, Length: 2003, dtype: int64

# %% [markdown]
# ## Pobieranie wynikow konkretnego gracza

# %%
vector=last_scores[last_scores['nazwisko']=='Dariusz Krakowiak']['nr_turnieju']

# %%
vector
# Out:
# 0     17666
# 1     17693
# 2     21728
# 3     21764
# 4     24150
# 5     24267
# 6     24303
# 7     25845
# 8     21800
# 9     22043
# 10    22079
# 11    24186
# 12    24222
# 13    24339
# 14    24384
# 15    25692
# 16    25737
# 17    25773
# 18    25809
# 19    25890
# Name: nr_turnieju, dtype: int64

# %%
history[29]
# Out:
#       id rozg  wynik  zapis linia  numer_rozdania
# 0      9   NS  90.94    110    NS              30
# 1      3   EW  43.59   -140    NS              30
# 2      2   EW  21.16   -170    NS              30
# 3      4   EW   1.94   -420    NS              30
# 4      7   EW   1.94   -420    NS              30
# ..   ...  ...    ...    ...   ...             ...
# 136  531   EW  78.84    170    EW              30
# 137  527   EW  78.84    170    EW              30
# 138  522   EW  78.84    170    EW              30
# 139  521   EW  56.41    140    EW              30
# 140  523   EW  78.84    170    EW              30
#
# [282 rows x 6 columns]

# %%
proba=[25890,25809]

# %%
history
# Out:
# [     Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1    3    7        3     N    2   =    140
#  1             1  DS/136      7    5    6        3     N    9  -1    -50
#  2             2  DS/136      8   10    8        3     S    3  -3   -150
#  3             3  DS/136      9    1    4      3 x     N    9  -2   -300
#  4             4  DS/136      6    2    9        3     W    J   =   -400
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      5  586  593        2     S    4  -1    -50
#  268         268  ZP/433      6  592  590        3     W    4  +1   -430
#  269         269  ZP/433      7  594  587        3     W    9  -1     50
#  270         270  ZP/433      8  585  591        3     E    J  +2   -150
#  271         271  ZP/433      9  584  595        2     N    2   =    110
#
#        % NS   % EW  Unnamed: 11
#  0    94.65   5.35          NaN
#  1    52.40  47.60          NaN
#  2    21.40  78.60          NaN
#  3    15.50  84.50          NaN
#  4     9.96  90.04          NaN
#  ..     ...    ...          ...
#  267  52.40  47.60          NaN
#  268   1.66  98.34          NaN
#  269  68.45  31.55          NaN
#  270  21.40  78.60          NaN
#  271  91.88   8.12          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1    3    7      4 x     N    J   =    790
#  1             1  DS/136      8   10    8      4 x     W    K  -2    300
#  2             2  DS/136      9    1    4      4 x     E    A  -2    300
#  3             3  DS/136      6    2    9        3     N    J   =    140
#  4             4  DS/136      7    5    6        4     N    6  -1   -100
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      5  586  593        4     S    5   =    620
#  268         268  ZP/433      6  592  590        3     W    J  -1     50
#  269         269  ZP/433      7  594  587        2     S    5  +2    170
#  270         270  ZP/433      8  585  591        4     N    6  -1   -100
#  271         271  ZP/433      9  584  595        4     W    K  -3    150
#
#        % NS   % EW  Unnamed: 11
#  0    99.08   0.92          NaN
#  1    78.04  21.96          NaN
#  2    78.04  21.96          NaN
#  3    40.78  59.22          NaN
#  4    14.95  85.05          NaN
#  ..     ...    ...          ...
#  267  89.30  10.70          NaN
#  268  24.72  75.28          NaN
#  269  62.18  37.82          NaN
#  270  14.95  85.05          NaN
#  271  50.55  49.45          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      9    1    4        2     N    8   =     90
#  1             1  DS/136      8   10    8        4     S    J  -1    -50
#  2             2  DS/136      1    3    7        3     S    7  -2   -100
#  3             3  DS/136      7    5    6        3     N    2  -2   -100
#  4             4  DS/136      6    2    9      5 x     S    6  -4   -800
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      5  586  593        3     S    7  -2   -100
#  268         268  ZP/433      6  592  590        3     N    J   =    110
#  269         269  ZP/433      7  594  587        3     S    6  -4   -200
#  270         270  ZP/433      8  585  591        3     S    7  -1    -50
#  271         271  ZP/433      9  584  595        3     S    7   =    110
#
#        % NS   % EW  Unnamed: 11
#  0    74.72  25.28          NaN
#  1    53.14  46.86          NaN
#  2    27.31  72.69          NaN
#  3    27.31  72.69          NaN
#  4     0.37  99.63          NaN
#  ..     ...    ...          ...
#  267  27.31  72.69          NaN
#  268  85.61  14.39          NaN
#  269   8.12  91.88          NaN
#  270  53.14  46.86          NaN
#  271  85.61  14.39          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      9   10    9        3     W    K  -4    400
#  1             1  DS/136      1    2    5        3     E    7  -2    200
#  2             2  DS/136      2    4    8        3     E    7  -1    100
#  3             3  DS/136      7    3    1        3     N    Q  -1   -100
#  4             4  DS/136      8    6    7        1     E    7  +1   -120
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  596  584        3     N    Q  -2   -200
#  268         268  ZP/433      6  587  593        2     N    8  -1   -100
#  269         269  ZP/433      7  583  591        3     E    7  -2    200
#  270         270  ZP/433      8  594  588        3     E    7   =   -600
#  271         271  ZP/433      9  586  592        3     N    Q  -2   -200
#
#        % NS   % EW  Unnamed: 11
#  0    97.42   2.58          NaN
#  1    88.38  11.62          NaN
#  2    73.06  26.94          NaN
#  3    58.86  41.14          NaN
#  4    51.48  48.52          NaN
#  ..     ...    ...          ...
#  267  37.45  62.55          NaN
#  268  58.86  41.14          NaN
#  269  88.38  11.62          NaN
#  270  12.36  87.64          NaN
#  271  37.45  62.55          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1    2    5        1     N    J  -1   -100
#  1             1  DS/136      7    3    1        1     E   10  +2   -150
#  2             2  DS/136      9   10    9        1     W    2  +2   -150
#  3             3  DS/136      8    6    7        1     N    6  -3   -300
#  4             4  DS/136      2    4    8        3     W    5   =   -400
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  596  584        1     E   10  +2   -150
#  268         268  ZP/433      6  587  593        1     E   10  +2   -150
#  269         269  ZP/433      7  583  591      2 x     S    9  -2   -500
#  270         270  ZP/433      8  594  588      3 x     S    3  -2   -500
#  271         271  ZP/433      9  586  592        2     S    9  -3   -300
#
#        % NS   % EW  Unnamed: 11
#  0    83.95  16.05          NaN
#  1    52.03  47.97          NaN
#  2    52.03  47.97          NaN
#  3    19.37  80.63          NaN
#  4    12.36  87.64          NaN
#  ..     ...    ...          ...
#  267  52.03  47.97          NaN
#  268  52.03  47.97          NaN
#  269   4.43  95.57          NaN
#  270   4.43  95.57          NaN
#  271  19.37  80.63          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1    2    5      2 x     E    A  -1    200
#  1             1  DS/136      7    3    1        2     S    9   =     90
#  2             2  DS/136      8    6    7        2     S    K   =     90
#  3             3  DS/136      2    4    8        3     S    A  -3   -150
#  4             4  DS/136      9   10    9      5 x     N    K  -3   -500
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  596  584        3     S   10  -4   -200
#  268         268  ZP/433      6  587  593      3 x     S   10  -4   -800
#  269         269  ZP/433      7  583  591      3 x     S    A  -3   -500
#  270         270  ZP/433      8  594  588        3     S    5  -3   -150
#  271         271  ZP/433      9  586  592        3     S    K  -3   -150
#
#        % NS   % EW  Unnamed: 11
#  0    85.61  14.39          NaN
#  1    74.91  25.09          NaN
#  2    74.91  25.09          NaN
#  3    37.09  62.91          NaN
#  4    11.07  88.93          NaN
#  ..     ...    ...          ...
#  267  24.91  75.09          NaN
#  268   2.58  97.42          NaN
#  269  11.07  88.93          NaN
#  270  37.09  62.91          NaN
#  271  37.09  62.91          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1   10    1        4     S    Q  +2    680
#  1             1  DS/136      2    3    6        4     S    A  +2    680
#  2             2  DS/136      3    5    9        4     N    J  +2    680
#  3             3  DS/136      8    4    2        4     S    A  +2    680
#  4             4  DS/136      9    7    8        4     N    J  +2    680
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  591  590        2     S    K  -1   -100
#  268         268  ZP/433      3  596  585        4     S    A  +2    680
#  269         269  ZP/433      7  588  593        4     N    5  +2    680
#  270         270  ZP/433      8  584  592        4     S    Q  +2    680
#  271         271  ZP/433      9  594  589        4     N    J  +2    680
#
#        % NS   % EW  Unnamed: 11
#  0    60.33  39.67          NaN
#  1    60.33  39.67          NaN
#  2    60.33  39.67          NaN
#  3    60.33  39.67          NaN
#  4    60.33  39.67          NaN
#  ..     ...    ...          ...
#  267   8.49  91.51          NaN
#  268  60.33  39.67          NaN
#  269  60.33  39.67          NaN
#  270  60.33  39.67          NaN
#  271  60.33  39.67          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1   10    1      4 x     E    K  -2  300.0
#  1             1  DS/136      2    3    6        3     N    K  +1  130.0
#  2             2  DS/136      8    4    2        3     S    3  +1  130.0
#  3             3  DS/136      3    5    9        3     E    J  -1   50.0
#  4             4  DS/136      9    7    8        3     S    3  -2 -100.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  591  590        3     S    5  -1  -50.0
#  268         268  ZP/433      3  596  585      4 x     E    K  -2  300.0
#  269         269  ZP/433      7  588  593      3 x     E    K  -1  100.0
#  270         270  ZP/433      8  584  592        4     N    K   =  130.0
#  271         271  ZP/433      9  594  589        4     N    6  -1  -50.0
#
#        % NS   % EW  Unnamed: 11
#  0    84.07  15.93          NaN
#  1    68.89  31.11          NaN
#  2    68.89  31.11          NaN
#  3    37.41  62.59          NaN
#  4    13.15  86.85          NaN
#  ..     ...    ...          ...
#  267  21.85  78.15          NaN
#  268  84.07  15.93          NaN
#  269  50.93  49.07          NaN
#  270  68.89  31.11          NaN
#  271  21.85  78.15          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      2    3    6        2     W    A  +1 -110.0
#  1             1  DS/136      9    7    8        2     W    A  +1 -110.0
#  2             2  DS/136      1   10    1        2     W    A  +2 -130.0
#  3             3  DS/136      3    5    9        3     W    5  +1 -630.0
#  4             4  DS/136      8    4    2        3     W    A  +1 -630.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  591  590        3     W    8  -1  100.0
#  268         268  ZP/433      3  596  585        3     W   10   = -600.0
#  269         269  ZP/433      7  588  593        2     W    A   =  -90.0
#  270         270  ZP/433      8  584  592        3     W    7   = -600.0
#  271         271  ZP/433      9  594  589        4     S    K  -3 -150.0
#
#        % NS   % EW  Unnamed: 11
#  0    77.04  22.96          NaN
#  1    77.04  22.96          NaN
#  2    66.48  33.52          NaN
#  3    11.48  88.52          NaN
#  4    11.48  88.52          NaN
#  ..     ...    ...          ...
#  267  90.37   9.63          NaN
#  268  32.59  67.41          NaN
#  269  84.63  15.37          NaN
#  270  32.59  67.41          NaN
#  271  53.89  46.11          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW  kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1    8    9       3.0     W    3  -1    100
#  1             1  DS/136      4    6    1       1.0     E    3  -1    100
#  2             2  DS/136      9    5    3       2.0     E    3  -1    100
#  3             3  DS/136      2   10    2       1.0     E    5   =    -90
#  4             4  DS/136      3    4    7       1.0     E    3   =    -90
#  ..          ...     ...    ...  ...  ...       ...   ...  ...  ..    ...
#  267         267  ZP/433      2  587  595       1.0     E    3   =    -90
#  268         268  ZP/433      3  592  591       1.0     E    3   =    -90
#  269         269  ZP/433      4  596  586       1.0     E    2   =    -90
#  270         270  ZP/433      8  589  593       3.0     E    3  -2    200
#  271         271  ZP/433      9  585  583       3.0     E    3  -2    200
#
#        % NS   % EW  Unnamed: 11
#  0    72.32  27.68          NaN
#  1    72.32  27.68          NaN
#  2    72.32  27.68          NaN
#  3    37.64  62.36          NaN
#  4    37.64  62.36          NaN
#  ..     ...    ...          ...
#  267  37.64  62.36          NaN
#  268  37.64  62.36          NaN
#  269  37.64  62.36          NaN
#  270  90.96   9.04          NaN
#  271  90.96   9.04          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      9    5    3      4 x     S    A  +1    690
#  1             1  DS/136      3    4    7      5 x     S    A   =    650
#  2             2  DS/136      2   10    2      5 x     W    A  -2    300
#  3             3  DS/136      4    6    1      5 x     W    A  -2    300
#  4             4  DS/136      1    8    9      5 x     E    6  -1    100
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  587  595      5 x     W    A  -1    100
#  268         268  ZP/433      3  592  591      5 x     W    A  -2    300
#  269         269  ZP/433      4  596  586      5 x     W    A  -3    500
#  270         270  ZP/433      8  589  593      5 x     W    A  -2    300
#  271         271  ZP/433      9  585  583      5 x     W    A  -2    300
#
#        % NS   % EW  Unnamed: 11
#  0    93.54   6.46          NaN
#  1    87.82  12.18          NaN
#  2    48.52  51.48          NaN
#  3    48.52  51.48          NaN
#  4    28.41  71.59          NaN
#  ..     ...    ...          ...
#  267  28.41  71.59          NaN
#  268  48.52  51.48          NaN
#  269  73.06  26.94          NaN
#  270  48.52  51.48          NaN
#  271  48.52  51.48          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      4    6    1        3     S    K  +1    630
#  1             1  DS/136      3    4    7        2     S    A   =    120
#  2             2  DS/136      2   10    2        2     S    A  +1    110
#  3             3  DS/136      1    8    9        3     S    4  -1   -100
#  4             4  DS/136      9    5    3        3     S    4  -1   -100
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  587  595        3     S    A  -2   -200
#  268         268  ZP/433      3  592  591        2     S    A  +1    110
#  269         269  ZP/433      4  596  586        3     N    2  -3   -300
#  270         270  ZP/433      8  589  593        4     N    7   =    130
#  271         271  ZP/433      9  585  583        3     S    A   =    110
#
#        % NS   % EW  Unnamed: 11
#  0    97.60   2.40          NaN
#  1    71.96  28.04          NaN
#  2    59.22  40.78          NaN
#  3    31.92  68.08          NaN
#  4    31.92  68.08          NaN
#  ..     ...    ...          ...
#  267  12.92  87.08          NaN
#  268  59.22  40.78          NaN
#  269   6.64  93.36          NaN
#  270  78.78  21.22          NaN
#  271  59.22  40.78          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1    6    4        1     N    K  +2  140.0
#  1             1  DS/136      2    9    1        2     N    4   =  120.0
#  2             2  DS/136      5    7    2        1     N    2  +1  120.0
#  3             3  DS/136      4    5    8        1     N    2   =   90.0
#  4             4  DS/136      3   10    3        3     N    2  -1 -100.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  589  585        1     N    K  +1  120.0
#  268         268  ZP/433      3  588  595        1     N    2  -2 -200.0
#  269         269  ZP/433      4  583  592        2     N    2  +1  110.0
#  270         270  ZP/433      5  596  587        1     N    2  +1  120.0
#  271         271  ZP/433      9  590  593      1 x     W    A  -2  500.0
#
#        % NS   % EW  Unnamed: 11
#  0    83.46  16.54          NaN
#  1    56.32  43.68          NaN
#  2    56.32  43.68          NaN
#  3    20.26  79.74          NaN
#  4    10.22  89.78          NaN
#  ..     ...    ...          ...
#  267  56.32  43.68          NaN
#  268   2.42  97.58          NaN
#  269  30.48  69.52          NaN
#  270  56.32  43.68          NaN
#  271  98.51   1.49          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      1    6    4        1     S    5   =     90
#  1             1  DS/136      2    9    1        3     S    3  -1    -50
#  2             2  DS/136      3   10    3        2     W    J   =   -110
#  3             3  DS/136      4    5    8        2     W    J   =   -110
#  4             4  DS/136      5    7    2        2     W    5   =   -110
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  589  585        2     E    3   =   -110
#  268         268  ZP/433      3  588  595        2     E    Q  +1   -110
#  269         269  ZP/433      4  583  592        1     S    5   =     90
#  270         270  ZP/433      5  596  587        2     W    7  +1   -140
#  271         271  ZP/433      9  590  593        3     E    3  -1     50
#
#        % NS   % EW  Unnamed: 11
#  0    69.19  30.81          NaN
#  1    40.96  59.04          NaN
#  2    23.25  76.75          NaN
#  3    23.25  76.75          NaN
#  4    23.25  76.75          NaN
#  ..     ...    ...          ...
#  267  23.25  76.75          NaN
#  268  23.25  76.75          NaN
#  269  69.19  30.81          NaN
#  270   8.67  91.33          NaN
#  271  50.92  49.08          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      2    9    1        3     N   10   =    600
#  1             1  DS/136      5    7    2        1     N    6  +2    150
#  2             2  DS/136      1    6    4        1     N    2  +1    120
#  3             3  DS/136      3   10    3        3     N    6  -1   -100
#  4             4  DS/136      4    5    8      2 x     W    K  +1   -280
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  589  585        3     N    3  -1   -100
#  268         268  ZP/433      3  588  595        3     N    6  -1   -100
#  269         269  ZP/433      4  583  592        3     N   10   =    600
#  270         270  ZP/433      5  596  587        3     N    6  -1   -100
#  271         271  ZP/433      9  590  593        3     N    3  -1   -100
#
#        % NS   % EW  Unnamed: 11
#  0    90.22   9.78          NaN
#  1    75.09  24.91          NaN
#  2    59.04  40.96          NaN
#  3    23.99  76.01          NaN
#  4     0.37  99.63          NaN
#  ..     ...    ...          ...
#  267  23.99  76.01          NaN
#  268  23.99  76.01          NaN
#  269  90.22   9.78          NaN
#  270  23.99  76.01          NaN
#  271  23.99  76.01          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW  kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      5    6    9       6.0     S    2   =    990
#  1             1  DS/136      4   10    4       4.0     N    8  +2    480
#  2             2  DS/136      6    8    3       4.0     N    A  +2    480
#  3             3  DS/136      2    7    5       5.0     N   10   =    450
#  4             4  DS/136      3    1    2       4.0     N   10  +1    450
#  ..          ...     ...    ...  ...  ...       ...   ...  ...  ..    ...
#  267         267  ZP/433      2  594  592       4.0     N   10  +2    480
#  268         268  ZP/433      3  590  586       4.0     N   10  +1    450
#  269         269  ZP/433      4  589  595       4.0     N    8  +2    480
#  270         270  ZP/433      5  584  583       4.0     N    8  +1    450
#  271         271  ZP/433      6  596  588       5.0     N   10   =    450
#
#        % NS   % EW  Unnamed: 11
#  0    99.08   0.92          NaN
#  1    62.36  37.64          NaN
#  2    62.36  37.64          NaN
#  3    22.14  77.86          NaN
#  4    22.14  77.86          NaN
#  ..     ...    ...          ...
#  267  62.36  37.64          NaN
#  268  22.14  77.86          NaN
#  269  62.36  37.64          NaN
#  270  22.14  77.86          NaN
#  271  22.14  77.86          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      2    7    5        3     E    Q  +1 -170.0
#  1             1  DS/136      5    6    9        3     E    6  +2 -200.0
#  2             2  DS/136      3    1    2        4     E    3  +1 -450.0
#  3             3  DS/136      4   10    4        4     E    Q  +1 -450.0
#  4             4  DS/136      6    8    3        4     E    6  +1 -450.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  594  592        5     N    K  -1  -50.0
#  268         268  ZP/433      3  590  586        4     N    K  -1  -50.0
#  269         269  ZP/433      4  589  595        4     N    A  -1  -50.0
#  270         270  ZP/433      5  584  583        5     N    A  -2 -100.0
#  271         271  ZP/433      6  596  588      5 x     N    A  -2 -300.0
#
#        % NS   % EW  Unnamed: 11
#  0    72.96  27.04          NaN
#  1    60.37  39.63          NaN
#  2    12.59  87.41          NaN
#  3    12.59  87.41          NaN
#  4    12.59  87.41          NaN
#  ..     ...    ...          ...
#  267  89.26  10.74          NaN
#  268  89.26  10.74          NaN
#  269  89.26  10.74          NaN
#  270  81.85  18.15          NaN
#  271  45.19  54.81          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      3    1    2      4 x     E    A  -2    300
#  1             1  DS/136      4   10    4        2     N    J  +1    110
#  2             2  DS/136      2    7    5        3     E    5  -2    100
#  3             3  DS/136      6    8    3        2     E    4   =   -110
#  4             4  DS/136      5    6    9      3 x     S    9  -2   -500
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  267         267  ZP/433      2  594  592        3     N    J   =    110
#  268         268  ZP/433      3  590  586        4     N    J   =    130
#  269         269  ZP/433      4  589  595        2     N    J  +2    130
#  270         270  ZP/433      5  584  583      5 x     N    A  -3   -800
#  271         271  ZP/433      6  596  588        4     N    A   =    130
#
#        % NS   % EW  Unnamed: 11
#  0    90.96   9.04          NaN
#  1    66.79  33.21          NaN
#  2    57.56  42.44          NaN
#  3    24.54  75.46          NaN
#  4     2.03  97.97          NaN
#  ..     ...    ...          ...
#  267  66.79  33.21          NaN
#  268  76.75  23.25          NaN
#  269  76.75  23.25          NaN
#  270   0.37  99.63          NaN
#  271  76.75  23.25          NaN
#
#  [272 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      3    8    6      2 x     W    K  -2    500
#  1             1  DS/136      7    9    4        3     N   10  +2    460
#  2             2  DS/136      6    7    1        1     N    4  +4    210
#  3             3  DS/136      4    2    3        1     N    4  +3    180
#  4             4  DS/136      5   10    5        2     N    5  +2    180
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      3  594  583        3     S    4  +2    460
#  269         269  ZP/433      4  591  587        3     N   10   =    400
#  270         270  ZP/433      5  590  595        1     N    5  +4    210
#  271         271  ZP/433      6  585  584        1     N    5  +3    180
#  272         272  ZP/433      7  596  589        3     N    5   =    400
#
#        % NS   % EW  Unnamed: 11
#  0    95.96   4.04          NaN
#  1    90.07   9.93          NaN
#  2    60.29  39.71          NaN
#  3    42.10  57.90          NaN
#  4    42.10  57.90          NaN
#  ..     ...    ...          ...
#  268  90.07   9.93          NaN
#  269  75.74  24.26          NaN
#  270  60.29  39.71          NaN
#  271  42.10  57.90          NaN
#  272  75.74  24.26          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      4    2    3        3     N    Q  +1    630
#  1             1  DS/136      6    7    1        2     N    Q   =    120
#  2             2  DS/136      3    8    6        3     N    Q  -1   -100
#  3             3  DS/136      5   10    5        3     S    7  -1   -100
#  4             4  DS/136      7    9    4        3     N    Q  -1   -100
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      3  594  583        3     S    Q   =    600
#  269         269  ZP/433      4  591  587        3     S    7  -1   -100
#  270         270  ZP/433      5  590  595        3     N    Q  +1    630
#  271         271  ZP/433      6  585  584        4     S    2  -3   -300
#  272         272  ZP/433      7  596  589        3     N    Q  -1   -100
#
#        % NS   % EW  Unnamed: 11
#  0    80.51  19.49          NaN
#  1    54.04  45.96          NaN
#  2    27.57  72.43          NaN
#  3    27.57  72.43          NaN
#  4    27.57  72.43          NaN
#  ..     ...    ...          ...
#  268  64.89  35.11          NaN
#  269  27.57  72.43          NaN
#  270  80.51  19.49          NaN
#  271   0.55  99.45          NaN
#  272  27.57  72.43          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      7    9    4        4     E    2  -3  150.0
#  1             1  DS/136      3    8    6        4     W    Q  -2  100.0
#  2             2  DS/136      6    7    1        3     W    Q  -2  100.0
#  3             3  DS/136      4    2    3        4     E    K   = -420.0
#  4             4  DS/136      5   10    5      4 x     S    A  -3 -800.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      3  594  583        4     E    2   = -420.0
#  269         269  ZP/433      4  591  587        4     E    6   = -420.0
#  270         270  ZP/433      5  590  595      2 x     S    A   =  670.0
#  271         271  ZP/433      6  585  584        4     W    Q  +1 -450.0
#  272         272  ZP/433      7  596  589        4     E    K   = -420.0
#
#        % NS   % EW  Unnamed: 11
#  0    97.60   2.40          NaN
#  1    88.01  11.99          NaN
#  2    88.01  11.99          NaN
#  3    26.57  73.43          NaN
#  4     0.19  99.81          NaN
#  ..     ...    ...          ...
#  268  26.57  73.43          NaN
#  269  26.57  73.43          NaN
#  270  99.45   0.55          NaN
#  271   8.12  91.88          NaN
#  272  26.57  73.43          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      6   10    6        3     N    5  +3    490
#  1             1  DS/136      7    8    2        5     N    A   =    400
#  2             2  DS/136      8    1    5        5     N    A   =    400
#  3             3  DS/136      5    3    4        2     S    K  +2    170
#  4             4  DS/136      4    9    7        3     N    2  -1    -50
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      4  594  584        6     N    2  -1    -50
#  269         269  ZP/433      5  592  588        5     S    K   =    400
#  270         270  ZP/433      6  591  595        6     N    K  -1    -50
#  271         271  ZP/433      7  586  585        3     N    K   =    400
#  272         272  ZP/433      8  596  590        5     N    A   =    400
#
#        % NS   % EW  Unnamed: 11
#  0    96.14   3.86          NaN
#  1    51.65  48.35          NaN
#  2    51.65  48.35          NaN
#  3    31.07  68.93          NaN
#  4    12.87  87.13          NaN
#  ..     ...    ...          ...
#  268  12.87  87.13          NaN
#  269  51.65  48.35          NaN
#  270  12.87  87.13          NaN
#  271  51.65  48.35          NaN
#  272  51.65  48.35          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      7    8    2        2     W    7  -1    100
#  1             1  DS/136      4    9    7        1     W    5   =    -90
#  2             2  DS/136      6   10    6        2     W    2   =   -120
#  3             3  DS/136      5    3    4        1     W    5  +2   -150
#  4             4  DS/136      8    1    5        2     W    2  +2   -180
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      4  594  584        3     W    5   =   -110
#  269         269  ZP/433      5  592  588        3     W    8  -1    100
#  270         270  ZP/433      6  591  595        3     W    2   =   -110
#  271         271  ZP/433      7  586  585        1     W    2  +1   -120
#  272         272  ZP/433      8  596  590        2     E    8  -2    200
#
#        % NS   % EW  Unnamed: 11
#  0    80.88  19.12          NaN
#  1    60.85  39.15          NaN
#  2    27.57  72.43          NaN
#  3    15.99  84.01          NaN
#  4    13.42  86.58          NaN
#  ..     ...    ...          ...
#  268  41.54  58.46          NaN
#  269  80.88  19.12          NaN
#  270  41.54  58.46          NaN
#  271  27.57  72.43          NaN
#  272  94.49   5.51          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      8    1    5        3     E    4  -3  150.0
#  1             1  DS/136      5    3    4        2     S   10   =   90.0
#  2             2  DS/136      4    9    7        3     W    Q  -1   50.0
#  3             3  DS/136      6   10    6        2     E    2  -1   50.0
#  4             4  DS/136      7    8    2        2     N    6  -2 -100.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      4  594  584        2     E    K  -3  150.0
#  269         269  ZP/433      5  592  588        2     S   10   =   90.0
#  270         270  ZP/433      6  591  595        3     W    Q  -1   50.0
#  271         271  ZP/433      7  586  585        3     W    Q  -1   50.0
#  272         272  ZP/433      8  596  590        2     E    2  -1   50.0
#
#        % NS   % EW  Unnamed: 11
#  0    95.20   4.80          NaN
#  1    61.99  38.01          NaN
#  2    39.30  60.70          NaN
#  3    39.30  60.70          NaN
#  4    10.33  89.67          NaN
#  ..     ...    ...          ...
#  268  95.20   4.80          NaN
#  269  61.99  38.01          NaN
#  270  39.30  60.70          NaN
#  271  39.30  60.70          NaN
#  272  39.30  60.70          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      8    9    3      3 x     S    Q  +1  570.0
#  1             1  DS/136      7   10    7        1     N    9  +1  120.0
#  2             2  DS/136      5    1    8        2     S   10   =  110.0
#  3             3  DS/136      9    2    6        1     E    6   =  -90.0
#  4             4  DS/136      6    4    5        3     N    3  -3 -150.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      5  594  585        3     S    8  +1  130.0
#  269         269  ZP/433      6  583  589        2     W    K  +1 -140.0
#  270         270  ZP/433      7  592  595        2     S   10   =  110.0
#  271         271  ZP/433      8  587  586        2     W   10  +1 -140.0
#  272         272  ZP/433      9  596  591        3     W   10  -2  200.0
#
#        % NS   % EW  Unnamed: 11
#  0    98.52   1.48          NaN
#  1    73.25  26.75          NaN
#  2    67.16  32.84          NaN
#  3    43.73  56.27          NaN
#  4     6.27  93.73          NaN
#  ..     ...    ...          ...
#  268  77.12  22.88          NaN
#  269  20.30  79.70          NaN
#  270  67.16  32.84          NaN
#  271  20.30  79.70          NaN
#  272  88.38  11.62          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist  lew  zapis  \
#  0             0  DS/136      7   10    7        4     N    A   +1  650.0
#  1             1  DS/136      9    2    6        5     S    A    =  600.0
#  2             2  DS/136      5    1    8        4     W    K   -1  100.0
#  3             3  DS/136      6    4    5        4     N    5   -1 -100.0
#  4             4  DS/136      8    9    3        5     S    8   -1 -100.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ...    ...
#  268         268  ZP/433      5  594  585        4     N    K   -2 -200.0
#  269         269  ZP/433      6  583  589       TD   NaN  NaN  NaN    NaN
#  270         270  ZP/433      7  592  595        4     N    K    =  620.0
#  271         271  ZP/433      8  587  586        3     N    K   -1 -100.0
#  272         272  ZP/433      9  596  591        4     N    K    =  620.0
#
#        % NS   % EW  Unnamed: 11
#  0    93.54   6.46          NaN
#  1    79.15  20.85          NaN
#  2    52.40  47.60          NaN
#  3    42.25  57.75          NaN
#  4    42.25  57.75          NaN
#  ..     ...    ...          ...
#  268  21.40  78.60          NaN
#  269  40.00  60.00          NaN
#  270  86.35  13.65          NaN
#  271  42.25  57.75          NaN
#  272  86.35  13.65          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/136      6    4    5        2     W    9  +1   -140
#  1             1  DS/136      5    1    8        2     W    3  +2   -170
#  2             2  DS/136      9    2    6        3     W    K  +1   -170
#  3             3  DS/136      8    9    3      3 x     S    A  -2   -300
#  4             4  DS/136      7   10    7      4 x     W    K   =   -590
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  268         268  ZP/433      5  594  585        4     W    K   =   -420
#  269         269  ZP/433      6  583  589        2     S    K  -1    -50
#  270         270  ZP/433      7  592  595        4     W    K   =   -420
#  271         271  ZP/433      8  587  586        4     W    K  -1     50
#  272         272  ZP/433      9  596  591        3     W    K  +1   -170
#
#        % NS   % EW  Unnamed: 11
#  0    58.82  41.18          NaN
#  1    46.14  53.86          NaN
#  2    46.14  53.86          NaN
#  3    38.42  61.58          NaN
#  4     5.15  94.85          NaN
#  ..     ...    ...          ...
#  268  23.90  76.10          NaN
#  269  67.65  32.35          NaN
#  270  23.90  76.10          NaN
#  271  81.43  18.57          NaN
#  272  46.14  53.86          NaN
#
#  [273 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew   zapis  \
#  0             0  DS/144      3   15   11        3     S    8  +1   170.0
#  1             1  DS/144      5   16   14        4     W    6   =  -420.0
#  2             2  DS/144      6   13   12     4 xx     S    8   =  1080.0
#  3             3  DS/269      2   22   26        4     W    K  -1    50.0
#  4             4  DS/269      3   20   19      4 x     S    8   =   790.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..     ...
#  215         215  ZP/433      5  591  589        5     E    A   =  -450.0
#  216         216  ZP/433      6  594  586      5 x     S    8  -1  -200.0
#  217         217  ZP/433      7  584  590        5     W    2  -3   150.0
#  218         218  ZP/433      8  583  595      5 x     W    A  -2   300.0
#  219         219  ZP/433      9  588  587      6 x     W    A  -1   100.0
#
#        % NS   % EW  Unnamed: 11
#  0    73.60  26.40          NaN
#  1    35.45  64.55          NaN
#  2    99.95   0.05          NaN
#  3    56.87  43.13          NaN
#  4    95.14   4.86          NaN
#  ..     ...    ...          ...
#  215  25.60  74.40          NaN
#  216  44.04  55.96          NaN
#  217  71.54  28.46          NaN
#  218  79.10  20.90          NaN
#  219  65.12  34.88          NaN
#
#  [220 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/269      2   22   26        2     E    8   =    -90
#  1             1  DS/269      3   20   19        1     E    Q  +2   -110
#  2             2  DS/269      5   27   24        2     S    Q  +2    170
#  3             3  DS/269      8   21   23        4     W    T  -3    300
#  4             4  DS/269     10   30   28        4     E    9  -2    200
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  197         197  ZP/433      5  591  589        2     N    K  +2    170
#  198         198  ZP/433      6  594  586        3     N    Q  +1    170
#  199         199  ZP/433      7  584  590        2     N    K  +1    140
#  200         200  ZP/433      8  583  595        3     N    K  +2    200
#  201         201  ZP/433      9  588  587        3     N    A  +1    170
#
#        % NS   % EW  Unnamed: 11
#  0     6.03  93.97          NaN
#  1     2.30  97.70          NaN
#  2    34.10  65.90          NaN
#  3    83.54  16.46          NaN
#  4    63.66  36.34          NaN
#  ..     ...    ...          ...
#  197  34.10  65.90          NaN
#  198  34.10  65.90          NaN
#  199  20.44  79.56          NaN
#  200  63.66  36.34          NaN
#  201  34.10  65.90          NaN
#
#  [202 rows x 13 columns],
#       Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
#  0             0  DS/269      2   22   26        3     S    A  +2  200.0
#  1             1  DS/269      3   20   19        4     S    A  +1  450.0
#  2             2  DS/269      5   27   24        3     N    K  +1  130.0
#  3             3  DS/269      8   21   23        3     N    5   =  400.0
#  4             4  DS/269     10   30   28        3     S    A  -2 -100.0
#  ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
#  197         197  ZP/433      5  591  589        4     S    A   =  420.0
#  198         198  ZP/433      6  594  586        3     S    A  +1  170.0
#  199         199  ZP/433      7  584  590        4     S    K  +1  450.0
#  200         200  ZP/433      8  583  595        3     N    5   =  400.0
#  201         201  ZP/433      9  588  587        4     N    6  +1  460.0
#
#        % NS   % EW  Unnamed: 11
#  0    39.51  60.49          NaN
#  1    83.21  16.79          NaN
#  2    15.55  84.45          NaN
#  3    47.50  52.50          NaN
#  4     2.81  97.19          NaN
#  ..     ...    ...          ...
#  197  55.24  44.76          NaN
#  198  29.53  70.47          NaN
#  199  83.21  16.79          NaN
#  200  47.50  52.50          NaN
#  201  92.94   7.06          NaN
#
#  [202 rows x 13 columns]]

# %%
history=get_hist(30,proba)

# %%
history=pipeline(history)
history=pipeline2(history)
history
# Out:
#       id rozg  wynik  nr_rozdania  nr_turnieju  zapis linia
# 0      8   EW  67.46            1        25890 -150.0    NS
# 1      5   EW  57.74            1        25890 -180.0    NS
# 2     10   EW  57.74            1        25890 -180.0    NS
# 3      3   EW  38.89            1        25890 -400.0    NS
# 4      4   EW  38.89            1        25890 -400.0    NS
# ..   ...  ...    ...          ...          ...    ...   ...
# 197  589   NS  44.76           30        25809 -420.0    EW
# 198  586   NS  70.47           30        25809 -170.0    EW
# 199  590   NS  16.79           30        25809 -450.0    EW
# 200  595   NS  52.50           30        25809 -400.0    EW
# 201  587   NS   7.06           30        25809 -460.0    EW
#
# [30006 rows x 7 columns]

# %%
len(history)
# Out:
# 15003

# %%
tmp=pd.DataFrame(history[0])

# %%
tmp
# Out:
#      Unnamed: 0 ośrodek  runda   NS   EW kontrakt rozg. wist lew  zapis  \
# 0             0  DS/136      5    8   11        2     E    8  +1   -150
# 1             1  DS/136      3    5    9        1     W    5  +3   -180
# 2             2  DS/136      6   10    7        2     E    3  +2   -180
# 3             3  DS/136      4    3    2        3     E    3   =   -400
# 4             4  DS/136      9    4    6        3     E    8   =   -400
# ..          ...     ...    ...  ...  ...      ...   ...  ...  ..    ...
# 248         248  ZP/452     11  530  532        3     E    3  -2    100
# 249         249  ZP/452     12  525  528        3     E    6   =   -400
# 250         250  ZP/452     13  527  523        3     W    5   =   -400
# 251         251  ZP/452     14  529  522        3     W    5  +1   -430
# 252         252  ZP/452     15  533  524        3     E    6   =   -400
#
#       % NS   % EW  Unnamed: 11  nr_rozdania  nr_turnieju
# 0    67.46  32.54          NaN            1        25890
# 1    57.74  42.26          NaN            1        25890
# 2    57.74  42.26          NaN            1        25890
# 3    38.89  61.11          NaN            1        25890
# 4    38.89  61.11          NaN            1        25890
# ..     ...    ...          ...          ...          ...
# 248  98.61   1.39          NaN            1        25890
# 249  38.89  61.11          NaN            1        25890
# 250  38.89  61.11          NaN            1        25890
# 251  13.29  86.71          NaN            1        25890
# 252  38.89  61.11          NaN            1        25890
#
# [253 rows x 15 columns]

# %% [markdown]
# ### TODO
# numer borda, numer turnieju, konkatencja

# %% [markdown]
# ## Pobieranie wyników z poszczególnych turniejów

# %%
proba=[25845,25809,25773,25737,25692,24384,24339,24303,24267,24222,24186,24150,22079 ,22043 ,21800,21764,21728,17693,17666]
history=get_hist(30,proba)   
history=pipeline(history)
history=pipeline2(history)
history
# Out:
#       id rozg  wynik  nr_rozdania  nr_turnieju  zapis linia
# 0      4   EW  99.21            1        25845  500.0    NS
# 1      6   NS  93.68            1        25845  460.0    NS
# 2     10   NS  88.93            1        25845  450.0    NS
# 3      5   NS  82.02            1        25845  430.0    NS
# 4      2   NS  40.12            1        25845  140.0    NS
# ..   ...  ...    ...          ...          ...    ...   ...
# 347  780   EW  84.00           30        17666  990.0    EW
# 348  776   EW  84.00           30        17666  990.0    EW
# 349  772   EW  84.00           30        17666  990.0    EW
# 350  778   EW  53.29           30        17666  980.0    EW
# 351  777   EW   3.00           30        17666  230.0    EW
#
# [255094 rows x 7 columns]

# %%
last_scores
# Out:
#        m-ce   nr      %  nr_turnieju              nazwisko   wk    PID
# 0         3  374  65.35        17666     Dariusz Krakowiak  3.0  17854
# 1        33  384  61.43        17693     Dariusz Krakowiak  3.0  17854
# 2       183  366  55.17        21728     Dariusz Krakowiak  3.0  17854
# 3        49  384  60.59        21764     Dariusz Krakowiak  3.0  17854
# 4        72   52  46.54        24150     Dariusz Krakowiak  3.0  17854
# ...     ...  ...    ...          ...                   ...  ...    ...
# 11754   232  176  51.10        25890        Andrzej Piętak  3.0  08323
# 11755   303  455  48.75        25890       Andrzej Grześko  2.0  19403
# 11756   321   20  48.22        25890  Tymoteusz Zaborowski  1.5  17787
# 11757   467  411  40.96        25890    Wiesław Kulikowski  1.5  15109
# 11758   522  249  24.82        25890       Matylda Brzyzka  0.0  21471
#
# [11759 rows x 7 columns]

# %%
tmp=history.merge(last_scores, left_on=['id','nr_turnieju'],right_on=['nr','nr_turnieju'])

# %%
tmp
# Out:
#          id rozg  wynik  nr_rozdania  nr_turnieju  zapis linia  m-ce   nr  \
# 0         4   EW  99.21            1        25845  500.0    NS   371    4
# 1         4   EW  99.21            1        25845  500.0    NS   371    4
# 2         4   EW  14.82            2        25845 -140.0    NS   371    4
# 3         4   EW  14.82            2        25845 -140.0    NS   371    4
# 4         4   NS  26.77            3        25845  170.0    NS   371    4
# ...     ...  ...    ...          ...          ...    ...   ...   ...  ...
# 274626  382   NS  50.57           28        17666 -140.0    EW   142  382
# 274627  382   NS  97.01           29        17666  100.0    EW   142  382
# 274628  382   NS  97.01           29        17666  100.0    EW   142  382
# 274629  382   EW  27.43           30        17666  490.0    EW   142  382
# 274630  382   EW  27.43           30        17666  490.0    EW   142  382
#
#             %           nazwisko   wk    PID
# 0       46.28  Stefan Małowiecki  4.0  01482
# 1       46.28     Zbigniew Bobak  4.0  01247
# 2       46.28  Stefan Małowiecki  4.0  01482
# 3       46.28     Zbigniew Bobak  4.0  01247
# 4       46.28  Stefan Małowiecki  4.0  01482
# ...       ...                ...  ...    ...
# 274626  56.07  Michał Szadkowski  0.0  18841
# 274627  56.07     Wojciech Wojsa  0.5  13918
# 274628  56.07  Michał Szadkowski  0.0  18841
# 274629  56.07     Wojciech Wojsa  0.5  13918
# 274630  56.07  Michał Szadkowski  0.0  18841
#
# [274631 rows x 13 columns]

# %%
tmp.to_csv("proba.csv")

# %%
tmp['nazwisko'].value_counts()
# Out:
# Dariusz Krakowiak       530
# Zbigniew Bobak          512
# Przemysław Wojtczak     511
# Dominik Głowacki        502
# Henryk Choiński         498
#                        ...
# Grzegorz Wasiak          23
# Jacek Węgrzyk            23
# Norbert Krzystanek       23
# Andrzej Górniakowski     23
# Robert Mroczek           23
# Name: nazwisko, Length: 1985, dtype: int64

# %% [markdown]
# ## Podział rozgrywka, obrona

# %%
zz=tmp[tmp['rozg']==tmp['linia']]
zz2=tmp[tmp['rozg']!=tmp['linia']]
zz['czy_rozgrywa']=True
zz2['czy_rozgrywa']=False
tmp=pd.concat([zz,zz2])

# %%
import math

# %%
tmp1=tmp[ (tmp['zapis']>0) & (tmp['czy_rozgrywa'] )]
tmp1['zapis2']=pd.cut(tmp['zapis'], bins=[0, 300, 900, math.inf],labels=['częściówka','końcówka','szlemik'], include_lowest=True)

# %%
tmp2=tmp[ (tmp['zapis']<0) & (tmp['czy_rozgrywa']==False )]
tmp2['zapis2']=pd.cut(tmp['zapis'], bins=[-math.inf,-900,-300,0],labels=['szlemik','końcówka','częściówka'], include_lowest=True)

# %%
tmp3=tmp[ (tmp['zapis']>=0) & (tmp['czy_rozgrywa']==False )]
tmp3['zapis2']='Kokosy_na_Obronie'

# %%
tmp4=tmp[ (tmp['zapis']<=0) & (tmp['czy_rozgrywa']==True )]
tmp4['zapis2']='Wpadka'

# %%
tmp=pd.concat([tmp1,tmp2,tmp3,tmp4])

# %% [markdown]
# ## Statystyki posczególnych zawodników

# %% [markdown]
# ### Średnie

# %%
stats2=tmp[tmp['czy_rozgrywa']==True].groupby(['PID'])['wynik'].mean().reset_index(name='średnia_na_rozgrywce')

# %%
stats3=tmp[tmp['czy_rozgrywa']==False].groupby(['PID'])['wynik'].mean().reset_index(name='średnia_na_obronie')

# %%
stat=stats2.merge(stats3,on='PID')

# %%
tmp
# Out:
#          id rozg  wynik  nr_rozdania  nr_turnieju  zapis linia  m-ce   nr  \
# 4         4   NS  26.77            3        25845  170.0    NS   371    4
# 5         4   NS  26.77            3        25845  170.0    NS   371    4
# 8         4   NS  63.39            8        25845  400.0    NS   371    4
# 9         4   NS  63.39            8        25845  400.0    NS   371    4
# 16        4   NS  51.98           18        25845  130.0    NS   371    4
# ...     ...  ...    ...          ...          ...    ...   ...   ...  ...
# 274570  244   EW  35.59           27        17666 -100.0    EW   286  244
# 274597  382   EW  59.75           14        17666  -50.0    EW   142  382
# 274598  382   EW  59.75           14        17666  -50.0    EW   142  382
# 274623  382   EW  35.59           27        17666 -100.0    EW   142  382
# 274624  382   EW  35.59           27        17666 -100.0    EW   142  382
#
#             %           nazwisko   wk    PID  czy_rozgrywa      zapis2
# 4       46.28  Stefan Małowiecki  4.0  01482          True  częściówka
# 5       46.28     Zbigniew Bobak  4.0  01247          True  częściówka
# 8       46.28  Stefan Małowiecki  4.0  01482          True    końcówka
# 9       46.28     Zbigniew Bobak  4.0  01247          True    końcówka
# 16      46.28  Stefan Małowiecki  4.0  01482          True  częściówka
# ...       ...                ...  ...    ...           ...         ...
# 274570  51.96   Jerzy Jakubowski  1.5  18390          True      Wpadka
# 274597  56.07     Wojciech Wojsa  0.5  13918          True      Wpadka
# 274598  56.07  Michał Szadkowski  0.0  18841          True      Wpadka
# 274623  56.07     Wojciech Wojsa  0.5  13918          True      Wpadka
# 274624  56.07  Michał Szadkowski  0.0  18841          True      Wpadka
#
# [273550 rows x 15 columns]

# %%
stat4=tmp[tmp['zapis2']=="Kokosy_na_Obronie"].groupby(['PID'])['wynik'].mean().reset_index(name="Kokosy_na_Obronie")
stat5=tmp[tmp['zapis2']=="częściówka"].groupby(['PID'])['wynik'].mean().reset_index(name="częściówka")
stat6=tmp[tmp['zapis2']=="końcówka"].groupby(['PID'])['wynik'].mean().reset_index(name="końcówka")
stat7=tmp[tmp['zapis2']=="szlemik"].groupby(['PID'])['wynik'].mean().reset_index(name="szlemik")
stat8=tmp[tmp['zapis2']=="Wpadka"].groupby(['PID'])['wynik'].mean().reset_index(name="Wpadka")

# %%
stat=stat.merge(stat4,on='PID')
stat=stat.merge(stat5,on='PID')
stat=stat.merge(stat6,on='PID')
stat=stat.merge(stat7,on='PID')
stat=stat.merge(stat8,on='PID')

# %%
stat[stat['PID']=='19080']
# Out:
#         PID  średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  \
# 1318  19080               58.3558           57.878437             83.805
#
#       częściówka   końcówka   szlemik     Wpadka
# 1318   57.814286  53.679524  72.25125  33.858462

# %%
stat.to_csv('statystyki_vol1.csv')

# %% [markdown]
# ### Count

# %%
stats2=tmp[tmp['czy_rozgrywa']==True].groupby(['PID'])['wynik'].count().reset_index(name='liczba_rozdan_na_rozgrywce')
stats3=tmp[tmp['czy_rozgrywa']==False].groupby(['PID'])['wynik'].count().reset_index(name='liczba_rozdan_na_obronie')
stat4=tmp[tmp['zapis2']=="Kokosy_na_Obronie"].groupby(['PID'])['wynik'].count().reset_index(name="liczba_rozdan_Kokosy_na_Obronie")
stat5=tmp[tmp['zapis2']=="częściówka"].groupby(['PID'])['wynik'].count().reset_index(name="liczba_rozdan_częściówka")
stat6=tmp[tmp['zapis2']=="końcówka"].groupby(['PID'])['wynik'].count().reset_index(name="liczba_rozdan_końcówka")
stat7=tmp[tmp['zapis2']=="szlemik"].groupby(['PID'])['wynik'].count().reset_index(name="liczba_rozdan_szlemik")
stat8=tmp[tmp['zapis2']=="Wpadka"].groupby(['PID'])['wynik'].count().reset_index(name="liczba_rozdan_Wpadka")

# %%
stat=stats2.merge(stats3,on='PID')
stat=stat.merge(stat4,on='PID')
stat=stat.merge(stat5,on='PID')
stat=stat.merge(stat6,on='PID')
stat=stat.merge(stat7,on='PID')
stat=stat.merge(stat8,on='PID')

# %%
stats=pd.read_csv('statystyki_vol1.csv')

# %%
koniec=pd.concat([stats,stat],axis=1)

# %%
koniec.to_csv("Ostateczne.csv")

# %% [markdown]
# --------------------

# %%
df_scores=pd.read_csv("Ostateczne.csv")
df_all=pd.read_csv("proba.csv")
df_stats=pd.read_csv("statystyki_vol1.csv")
df_players=pd.read_csv("Lista_Zawodnikow.csv")

# %%
df_scores=pd.read_csv("Ostateczne.csv")

# %%
df_players.columns
# Out:
# Index([                0,          'lokata',             'PID',
#        'imię i nazwisko',            'WZBS',              'WK',
#                     'TK',             'PKL',            'liga',
#         'klub / drużyna'],
#       dtype='object', name=0)

# %%
df_players = df_players.iloc[1:, :]

# %%
df_players=df_players.drop([0,'lokata'],axis=1)

# %%
df_scores=df_scores.drop(['Unnamed: 0.1', 'Unnamed: 0','PID.1'],axis=1)

# %%
import math

# %%
round(df_scores['średnia_na_rozgrywce']/max(df_scores['średnia_na_rozgrywce'])*100,2)
# Out:
# 0       51.76
# 1       63.41
# 2       82.92
# 3       57.37
# 4       69.56
#         ...
# 1748    67.74
# 1749    67.29
# 1750    61.51
# 1751    61.51
# 1752    57.52
# Name: średnia_na_rozgrywce, Length: 1753, dtype: float64

# %%
vector=['średnia_na_rozgrywce', 'średnia_na_obronie', 'Kokosy_na_Obronie', 'częściówka', 'końcówka', 'szlemik', 'Wpadka']

# %%
df_scores.columns
# Out:
# Index(['PID', 'średnia_na_rozgrywce', 'średnia_na_obronie',
#        'Kokosy_na_Obronie', 'częściówka', 'końcówka', 'szlemik', 'Wpadka',
#        'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
#        'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
#        'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
#        'liczba_rozdan_Wpadka'],
#       dtype='object')

# %%
df_new=pd.DataFrame({"PID":df_scores['PID']})

# %%
for i in vector:
    df_new[i]=round((df_scores[i]-min(df_scores[i]))/(max(df_scores[i])-min(df_scores[i]))*100,2)

# %%
df_new.describe()
# Out:
#                 PID  średnia_na_rozgrywce  średnia_na_obronie  \
# count   1753.000000           1753.000000         1753.000000
# mean   14016.372504             48.571683           52.771483
# std     6171.055033             14.530785           11.281895
# min      567.000000              0.000000            0.000000
# 25%     9588.000000             39.600000           46.290000
# 50%    16118.000000             49.310000           52.920000
# 75%    19031.000000             57.890000           59.760000
# max    22073.000000            100.000000          100.000000
#
#        Kokosy_na_Obronie   częściówka     końcówka      szlemik       Wpadka
# count        1753.000000  1753.000000  1753.000000  1753.000000  1753.000000
# mean           73.051301    49.855505    39.485602    46.358876    32.502453
# std             8.365169    14.203651    10.907494    19.600896     9.422030
# min             0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            68.870000    40.640000    33.260000    33.970000    27.150000
# 50%            73.510000    50.230000    39.820000    47.000000    31.830000
# 75%            78.400000    58.720000    45.610000    58.240000    37.280000
# max           100.000000   100.000000   100.000000   100.000000   100.000000

# %%
df_scores['PID']= df_scores['PID']. astype (str)
wektor=[]
for v in df_scores['PID']:
    wektor.append(v.rjust(5,'0'))
wektor
# Out:
# ['00567',
#  '01001',
#  '01005',
#  '01010',
#  '01056',
#  '01060',
#  '01072',
#  '01095',
#  '01101',
#  '01105',
#  '01108',
#  '01111',
#  '01117',
#  '01136',
#  '01139',
#  '01140',
#  '01157',
#  '01163',
#  '01164',
#  '01169',
#  '01218',
#  '01230',
#  '01247',
#  '01252',
#  '01282',
#  '01292',
#  '01313',
#  '01317',
#  '01318',
#  '01324',
#  '01328',
#  '01333',
#  '01341',
#  '01359',
#  '01363',
#  '01364',
#  '01366',
#  '01371',
#  '01378',
#  '01386',
#  '01390',
#  '01392',
#  '01399',
#  '01412',
#  '01418',
#  '01423',
#  '01434',
#  '01459',
#  '01465',
#  '01468',
#  '01482',
#  '01489',
#  '01492',
#  '01507',
#  '01510',
#  '01511',
#  '01512',
#  '01517',
#  '01521',
#  '01523',
#  '01532',
#  '01536',
#  '01538',
#  '01548',
#  '01562',
#  '01593',
#  '01596',
#  '01607',
#  '01616',
#  '01623',
#  '01628',
#  '01629',
#  '01633',
#  '01637',
#  '01638',
#  '01651',
#  '01660',
#  '01671',
#  '01676',
#  '01682',
#  '01708',
#  '01737',
#  '01738',
#  '01768',
#  '01795',
#  '01821',
#  '01824',
#  '01829',
#  '01849',
#  '01869',
#  '01873',
#  '01891',
#  '01893',
#  '01920',
#  '01928',
#  '01937',
#  '01938',
#  '01953',
#  '01965',
#  '01979',
#  '01988',
#  '01999',
#  '02008',
#  '02012',
#  '02017',
#  '02033',
#  '02034',
#  '02056',
#  '02074',
#  '02076',
#  '02086',
#  '02092',
#  '02112',
#  '02119',
#  '02141',
#  '02156',
#  '02188',
#  '02196',
#  '02197',
#  '02200',
#  '02202',
#  '02214',
#  '02229',
#  '02234',
#  '02243',
#  '02295',
#  '02320',
#  '02337',
#  '02377',
#  '02384',
#  '02413',
#  '02422',
#  '02433',
#  '02439',
#  '02445',
#  '02479',
#  '02514',
#  '02552',
#  '02618',
#  '02806',
#  '02850',
#  '02940',
#  '03021',
#  '03030',
#  '03036',
#  '03144',
#  '03262',
#  '03309',
#  '03311',
#  '03314',
#  '03333',
#  '03375',
#  '03428',
#  '03435',
#  '03461',
#  '03526',
#  '03577',
#  '03615',
#  '03636',
#  '03656',
#  '03670',
#  '03715',
#  '03731',
#  '03739',
#  '03743',
#  '03744',
#  '03751',
#  '03757',
#  '03758',
#  '03759',
#  '03786',
#  '03790',
#  '03800',
#  '03814',
#  '03855',
#  '03858',
#  '03908',
#  '03923',
#  '03966',
#  '04013',
#  '04017',
#  '04021',
#  '04025',
#  '04026',
#  '04030',
#  '04064',
#  '04066',
#  '04133',
#  '04136',
#  '04146',
#  '04152',
#  '04153',
#  '04171',
#  '04183',
#  '04189',
#  '04235',
#  '04248',
#  '04250',
#  '04265',
#  '04267',
#  '04281',
#  '04299',
#  '04304',
#  '04317',
#  '04325',
#  '04358',
#  '04381',
#  '04400',
#  '04438',
#  '04441',
#  '04455',
#  '04456',
#  '04480',
#  '04499',
#  '04506',
#  '04556',
#  '04608',
#  '04615',
#  '04634',
#  '04665',
#  '04668',
#  '04672',
#  '04720',
#  '04750',
#  '04767',
#  '04777',
#  '04780',
#  '04782',
#  '04791',
#  '04795',
#  '04806',
#  '04808',
#  '04818',
#  '04872',
#  '04873',
#  '04914',
#  '04945',
#  '04968',
#  '04992',
#  '05001',
#  '05010',
#  '05019',
#  '05055',
#  '05090',
#  '05096',
#  '05102',
#  '05116',
#  '05123',
#  '05150',
#  '05167',
#  '05186',
#  '05204',
#  '05217',
#  '05241',
#  '05253',
#  '05261',
#  '05295',
#  '05298',
#  '05304',
#  '05325',
#  '05327',
#  '05338',
#  '05339',
#  '05349',
#  '05358',
#  '05384',
#  '05420',
#  '05421',
#  '05532',
#  '05546',
#  '05555',
#  '05603',
#  '05637',
#  '05640',
#  '05662',
#  '05700',
#  '05737',
#  '05836',
#  '05850',
#  '05907',
#  '05921',
#  '05954',
#  '06003',
#  '06009',
#  '06021',
#  '06023',
#  '06040',
#  '06088',
#  '06099',
#  '06111',
#  '06140',
#  '06163',
#  '06173',
#  '06181',
#  '06194',
#  '06198',
#  '06209',
#  '06221',
#  '06248',
#  '06253',
#  '06255',
#  '06313',
#  '06341',
#  '06349',
#  '06357',
#  '06358',
#  '06475',
#  '06527',
#  '06530',
#  '06540',
#  '06669',
#  '06710',
#  '06811',
#  '06821',
#  '06905',
#  '06935',
#  '06951',
#  '06959',
#  '06973',
#  '06977',
#  '06992',
#  '07091',
#  '07135',
#  '07153',
#  '07154',
#  '07156',
#  '07166',
#  '07167',
#  '07169',
#  '07187',
#  '07208',
#  '07238',
#  '07327',
#  '07480',
#  '07486',
#  '07559',
#  '07575',
#  '07612',
#  '07656',
#  '07665',
#  '07717',
#  '07736',
#  '07750',
#  '07756',
#  '07786',
#  '07817',
#  '07869',
#  '07879',
#  '07882',
#  '07896',
#  '07910',
#  '07914',
#  '07925',
#  '07946',
#  '07952',
#  '07978',
#  '08004',
#  '08005',
#  '08011',
#  '08019',
#  '08032',
#  '08116',
#  '08143',
#  '08153',
#  '08155',
#  '08157',
#  '08190',
#  '08224',
#  '08225',
#  '08250',
#  '08252',
#  '08259',
#  '08274',
#  '08296',
#  '08315',
#  '08330',
#  '08348',
#  '08363',
#  '08377',
#  '08379',
#  '08389',
#  '08403',
#  '08416',
#  '08428',
#  '08532',
#  '08539',
#  '08541',
#  '08543',
#  '08555',
#  '08579',
#  '08602',
#  '08808',
#  '08819',
#  '08821',
#  '08833',
#  '08851',
#  '08880',
#  '08944',
#  '08951',
#  '08987',
#  '08990',
#  '09001',
#  '09042',
#  '09082',
#  '09115',
#  '09122',
#  '09170',
#  '09179',
#  '09184',
#  '09194',
#  '09197',
#  '09200',
#  '09204',
#  '09231',
#  '09242',
#  '09267',
#  '09278',
#  '09283',
#  '09287',
#  '09288',
#  '09291',
#  '09311',
#  '09345',
#  '09356',
#  '09365',
#  '09384',
#  '09385',
#  '09389',
#  '09427',
#  '09446',
#  '09455',
#  '09460',
#  '09461',
#  '09462',
#  '09506',
#  '09534',
#  '09569',
#  '09587',
#  '09588',
#  '09599',
#  '09616',
#  '09631',
#  '09652',
#  '09654',
#  '09675',
#  '09679',
#  '09704',
#  '09710',
#  '09735',
#  '09771',
#  '09773',
#  '09872',
#  '09929',
#  '10019',
#  '10020',
#  '10067',
#  '10096',
#  '10098',
#  '10107',
#  '10136',
#  '10143',
#  '10157',
#  '10158',
#  '10164',
#  '10183',
#  '10222',
#  '10224',
#  '10225',
#  '10235',
#  '10239',
#  '10301',
#  '10315',
#  '10318',
#  '10324',
#  '10340',
#  '10344',
#  '10350',
#  '10354',
#  '10356',
#  '10385',
#  '10402',
#  '10413',
#  '10425',
#  '10426',
#  '10434',
#  '10437',
#  '10439',
#  '10443',
#  '10447',
#  '10455',
#  '10456',
#  '10457',
#  '10465',
#  '10483',
#  '10503',
#  '10504',
#  '10559',
#  '10576',
#  '10577',
#  '10651',
#  '10711',
#  '10713',
#  '10719',
#  '10720',
#  '10724',
#  '10790',
#  '10798',
#  '10799',
#  '10821',
#  '10833',
#  '10862',
#  '10875',
#  '10893',
#  '10896',
#  '10897',
#  '10899',
#  '10913',
#  '10986',
#  '10988',
#  '10999',
#  '11089',
#  '11095',
#  '11157',
#  '11172',
#  '11187',
#  '11193',
#  '11195',
#  '11208',
#  '11219',
#  '11235',
#  '11244',
#  '11291',
#  '11331',
#  '11371',
#  '11400',
#  '11401',
#  '11435',
#  '11447',
#  '11451',
#  '11459',
#  '11490',
#  '11493',
#  '11503',
#  '11505',
#  '11506',
#  '11519',
#  '11533',
#  '11534',
#  '11562',
#  '11563',
#  '11572',
#  '11577',
#  '11582',
#  '11586',
#  '11588',
#  '11593',
#  '11594',
#  '11595',
#  '11615',
#  '11624',
#  '11658',
#  '11700',
#  '11710',
#  '11726',
#  '11747',
#  '11748',
#  '11758',
#  '11761',
#  '11785',
#  '11787',
#  '11810',
#  '11824',
#  '11851',
#  '11899',
#  '11900',
#  '11940',
#  '12000',
#  '12001',
#  '12002',
#  '12094',
#  '12203',
#  '12208',
#  '12224',
#  '12226',
#  '12250',
#  '12262',
#  '12264',
#  '12277',
#  '12278',
#  '12283',
#  '12295',
#  '12316',
#  '12317',
#  '12327',
#  '12331',
#  '12345',
#  '12346',
#  '12354',
#  '12376',
#  '12377',
#  '12380',
#  '12382',
#  '12383',
#  '12387',
#  '12416',
#  '12439',
#  '12446',
#  '12448',
#  '12452',
#  '12456',
#  '12464',
#  '12481',
#  '12508',
#  '12571',
#  '12573',
#  '12610',
#  '12629',
#  '12639',
#  '12650',
#  '12651',
#  '12668',
#  '12669',
#  '12676',
#  '12678',
#  '12680',
#  '12685',
#  '12691',
#  '12694',
#  '12709',
#  '12726',
#  '12771',
#  '12772',
#  '12778',
#  '12779',
#  '12802',
#  '12835',
#  '12861',
#  '12865',
#  '12868',
#  '12870',
#  '12872',
#  '12876',
#  '12884',
#  '12888',
#  '12889',
#  '12964',
#  '13082',
#  '13084',
#  '13088',
#  '13106',
#  '13114',
#  '13117',
#  '13118',
#  '13121',
#  '13122',
#  '13123',
#  '13124',
#  '13125',
#  '13126',
#  '13127',
#  '13166',
#  '13167',
#  '13179',
#  '13181',
#  '13214',
#  '13237',
#  '13249',
#  '13259',
#  '13282',
#  '13329',
#  '13339',
#  '13358',
#  '13359',
#  '13384',
#  '13385',
#  '13387',
#  '13406',
#  '13409',
#  '13422',
#  '13450',
#  '13463',
#  '13571',
#  '13580',
#  '13581',
#  '13583',
#  '13590',
#  '13603',
#  '13607',
#  '13625',
#  '13638',
#  '13657',
#  '13664',
#  '13695',
#  '13711',
#  '13721',
#  '13730',
#  '13749',
#  '13751',
#  '13762',
#  '13763',
#  '13767',
#  '13774',
#  '13775',
#  '13776',
#  '13784',
#  '13796',
#  '13830',
#  '13841',
#  '13843',
#  '13859',
#  '13866',
#  '13903',
#  '13905',
#  '13906',
#  '13911',
#  '13913',
#  '13918',
#  '13938',
#  '13939',
#  '13940',
#  '13992',
#  '13999',
#  '14006',
#  '14007',
#  '14051',
#  '14060',
#  '14090',
#  '14165',
#  '14181',
#  '14185',
#  '14230',
#  '14243',
#  '14282',
#  '14301',
#  '14302',
#  '14357',
#  '14364',
#  '14395',
#  '14397',
#  '14401',
#  '14407',
#  '14411',
#  '14416',
#  '14441',
#  '14442',
#  '14444',
#  '14445',
#  '14464',
#  '14465',
#  '14466',
#  '14474',
#  '14475',
#  '14491',
#  '14502',
#  '14503',
#  '14506',
#  '14508',
#  '14511',
#  '14515',
#  '14516',
#  '14520',
#  '14529',
#  '14534',
#  '14539',
#  '14563',
#  '14573',
#  '14576',
#  '14583',
#  '14586',
#  '14655',
#  '14660',
#  '14675',
#  '14691',
#  '14692',
#  '14694',
#  '14699',
#  '14714',
#  '14724',
#  '14725',
#  '14742',
#  '14754',
#  '14756',
#  '14767',
#  '14772',
#  '14789',
#  '14852',
#  '14867',
#  '14883',
#  '14939',
#  '14960',
#  '14982',
#  '15004',
#  '15038',
#  '15043',
#  '15044',
#  '15055',
#  '15057',
#  '15074',
#  '15082',
#  '15084',
#  '15086',
#  '15117',
#  '15123',
#  '15125',
#  '15131',
#  '15143',
#  '15156',
#  '15157',
#  '15194',
#  '15195',
#  '15213',
#  '15226',
#  '15228',
#  '15263',
#  '15267',
#  '15269',
#  '15312',
#  '15313',
#  '15324',
#  '15325',
#  '15338',
#  '15350',
#  '15351',
#  '15352',
#  '15353',
#  '15370',
#  '15371',
#  '15375',
#  '15398',
#  '15399',
#  '15460',
#  '15461',
#  '15625',
#  '15630',
#  '15632',
#  '15643',
#  '15644',
#  '15645',
#  '15655',
#  '15656',
#  '15677',
#  '15678',
#  '15687',
#  '15688',
#  '15700',
#  '15722',
#  '15733',
#  '15749',
#  '15751',
#  '15756',
#  '15768',
#  '15769',
#  '15770',
#  '15822',
#  '15825',
#  '15846',
#  '15850',
#  '15863',
#  '15865',
#  '15866',
#  '15868',
#  '15870',
#  '15871',
#  '15906',
#  '15913',
#  '15921',
#  '15949',
#  '15955',
#  '15957',
#  '15974',
#  '16053',
#  '16069',
#  '16082',
#  '16087',
#  '16092',
#  '16116',
#  '16118',
#  '16144',
#  '16147',
#  '16159',
#  '16173',
#  '16178',
#  '16180',
#  '16203',
#  '16213',
#  '16214',
#  '16217',
#  '16220',
#  '16221',
#  '16225',
#  '16226',
#  '16229',
#  '16230',
#  '16231',
#  '16233',
#  '16255',
#  '16257',
#  '16293',
#  '16296',
#  '16320',
#  '16323',
#  '16324',
#  '16325',
#  '16332',
#  '16336',
#  '16344',
#  '16368',
#  '16369',
#  '16370',
#  '16372',
#  '16373',
#  '16412',
#  '16413',
#  '16435',
#  '16439',
#  '16441',
#  '16446',
#  '16448',
#  '16450',
#  '16455',
#  '16460',
#  '16473',
#  '16495',
#  '16502',
#  '16528',
#  '16585',
#  '16586',
#  '16623',
#  '16637',
#  '16655',
#  '16669',
#  '16676',
#  '16677',
#  '16694',
#  '16699',
#  '16707',
#  '16712',
#  '16716',
#  '16718',
#  '16727',
#  '16728',
#  '16730',
#  '16738',
#  '16750',
#  '16756',
#  '16763',
#  '16776',
#  '16778',
#  '16780',
#  '16781',
#  '16784',
#  '16787',
#  '16789',
#  '16795',
#  '16799',
#  '16803',
#  '16810',
#  '16815',
#  '16816',
#  '16817',
#  '16853',
#  '16862',
#  '16873',
#  '16874',
#  '16881',
#  '16885',
#  '16886',
#  '16887',
#  '16888',
#  '16926',
#  '16936',
#  '16989',
#  '17006',
#  '17013',
#  '17024',
#  '17033',
#  '17036',
#  '17042',
#  '17048',
#  '17049',
#  '17051',
#  '17061',
#  '17157',
#  '17207',
#  '17208',
#  '17209',
#  '17221',
#  '17227',
#  '17228',
#  '17230',
#  '17232',
#  '17233',
#  '17250',
#  '17254',
#  '17257',
#  '17258',
#  '17265',
#  '17266',
#  '17270',
#  '17273',
#  ...]

# %%
df_scores['PID']=wektor

# %%
df_new #min-max scaler
# Out:
#         PID  średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  \
# 0       567                 23.77               78.62              91.37
# 1      1001                 42.18               43.88              72.98
# 2      1005                 73.01               59.11              74.28
# 3      1010                 32.63               47.75              71.58
# 4      1056                 51.90               53.48              74.66
# ...     ...                   ...                 ...                ...
# 1748  21958                 49.03               46.67              66.20
# 1749  21959                 48.31               46.21              65.26
# 1750  21971                 39.18               38.95              53.56
# 1751  21972                 39.18               38.95              53.56
# 1752  22073                 32.87               41.31              72.17
#
#       częściówka  końcówka  szlemik  Wpadka
# 0          59.47     24.05    29.54   27.67
# 1          44.33     38.92    48.97   28.90
# 2          51.63     66.36    79.57   47.18
# 3          37.24     30.10    39.42   27.70
# 4          49.23     37.51    59.18   31.51
# ...          ...       ...      ...     ...
# 1748       37.37     40.44    47.40   29.94
# 1749       40.84     40.59    45.32   30.00
# 1750       51.48     28.53    62.17   26.32
# 1751       51.48     28.53    62.17   26.32
# 1752       32.68     15.27    36.97   30.31
#
# [1753 rows x 8 columns]

# %%
vec=df_new['średnia_na_rozgrywce']
vec[vec<23.77].count()/len(vec)
# Out:
# 0.045636052481460354

# %%
df_score_upd=pd.DataFrame({'PID':df_scores['PID']})

# %%
for i in vector:
    vec=df_scores[i]
    wektor=[]
    for j in range(len(vec)):
        wektor.append(round((vec[vec<vec[j]].count()/len(vec))*100,2))
    df_score_upd[i]=wektor

# %%
df_scores
# Out:
#         PID  średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  \
# 0     10019             52.910000           30.508667          54.735000
# 1     10020             43.040571           43.570312          66.980000
# 2     10067             29.108235           34.573750          50.210000
# 3     10096             53.807391           58.210217          75.574545
# 4     10098             50.493618           47.151908          67.530312
# ...     ...                   ...                 ...                ...
# 1295  21958             48.582109           44.546628          64.042712
# 1296  21959             48.255241           44.294511          63.222381
# 1297  21971             44.113200           40.312632          53.076154
# 1298  21972             44.113200           40.312632          53.076154
# 1299  22073             41.248438           41.605625          69.222667
#
#       częściówka   końcówka    szlemik     Wpadka  liczba_rozdan_na_rozgrywce  \
# 0      30.860000  44.202727  57.400000  21.860000                          14
# 1      43.791250  38.664222  80.673333  26.448000                          70
# 2      48.064444  38.116667  25.663333   5.886250                          17
# 3      55.128148  57.882750  60.860000  27.940500                          69
# 4      49.366170  47.786860  45.357647  31.081250                         152
# ...          ...        ...        ...        ...                         ...
# 1295   42.296145  48.502970  47.395833  24.975111                         128
# 1296   43.933736  48.609720  45.321538  25.014545                         145
# 1297   48.960625  39.956800  62.165000  22.347500                          50
# 1298   48.960625  39.956800  62.165000  22.347500                          50
# 1299   40.077273  30.445333  36.968333  25.240000                          32
#
#       liczba_rozdan_na_obronie  liczba_rozdan_Kokosy_na_Obronie  \
# 0                           15                                4
# 1                           64                               21
# 2                            8                                2
# 3                           46                               22
# 4                          173                               64
# ...                        ...                              ...
# 1295                       172                               59
# 1296                       184                               63
# 1297                        38                               13
# 1298                        38                               13
# 1299                        48                               15
#
#       liczba_rozdan_częściówka  liczba_rozdan_końcówka  liczba_rozdan_szlemik  \
# 0                            5                      11                      4
# 1                           40                      45                      3
# 2                            9                       3                      3
# 3                           27                      40                      6
# 4                           94                      86                     17
# ...                        ...                     ...                    ...
# 1295                        83                     101                     12
# 1296                        91                     107                     13
# 1297                        32                      25                      2
# 1298                        32                      25                      2
# 1299                        33                      15                      6
#
#       liczba_rozdan_Wpadka         imię i nazwisko
# 0                        5       Maryla Zdrojewska
# 1                       25           Jerzy Słomski
# 2                        8        Andrzej Domański
# 3                       20         Adam Zdrojewski
# 4                       64     Franciszek Albekier
# ...                    ...                     ...
# 1295                    45            Janusz Piłat
# 1296                    55          Wiesław Wójcik
# 1297                    16              Ewa Powała
# 1298                    16         Sławomir Powała
# 1299                    11  Waldemar Rozmarynowski
#
# [1300 rows x 16 columns]

# %%
df_score_upd
# Out:
#         PID  średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  \
# 0     00567                  4.56               98.80              98.69
# 1     01001                 31.72               18.82              46.83
# 2     01005                 95.66               73.02              53.68
# 3     01010                 12.49               29.26              38.16
# 4     01056                 57.50               52.25              55.79
# ...     ...                   ...                 ...                ...
# 1748  21958                 49.12               26.07              16.60
# 1749  21959                 47.01               24.47              14.15
# 1750  21971                 23.96                9.53               1.65
# 1751  21972                 23.96                9.53               1.65
# 1752  22073                 12.78               13.63              41.53
#
#       częściówka  końcówka  szlemik  Wpadka  liczba_rozdan_na_rozgrywce  \
# 0          76.44      7.53    18.03   27.90                          15
# 1          33.94     46.49    54.31   32.80                         136
# 2          54.59     98.23    94.07   94.52                          14
# 3          17.40     16.83    35.65   28.07                         125
# 4          46.26     41.59    76.55   47.46                          92
# ...          ...       ...      ...     ...                         ...
# 1748       17.57     52.99    50.77   39.08                         128
# 1749       25.56     53.85    46.38   39.25                         145
# 1750       54.02     12.66    81.63   20.65                          50
# 1751       54.02     12.66    81.63   20.65                          50
# 1752       10.78      2.28    30.18   40.96                          32
#
#       liczba_rozdan_na_obronie  liczba_rozdan_Kokosy_na_Obronie  \
# 0                           14                                8
# 1                          116                               29
# 2                           15                                7
# 3                          155                               56
# 4                          123                               42
# ...                        ...                              ...
# 1748                       172                               59
# 1749                       184                               63
# 1750                        38                               13
# 1751                        38                               13
# 1752                        48                               15
#
#       liczba_rozdan_częściówka  liczba_rozdan_końcówka  liczba_rozdan_szlemik  \
# 0                            6                       4                      3
# 1                           53                     102                     10
# 2                           13                       3                      1
# 3                           77                      87                      4
# 4                           65                      64                      9
# ...                        ...                     ...                    ...
# 1748                        83                     101                     12
# 1749                        91                     107                     13
# 1750                        32                      25                      2
# 1751                        32                      25                      2
# 1752                        33                      15                      6
#
#       liczba_rozdan_Wpadka         imię i nazwisko
# 0                        8    Jarosław Kaczorowski
# 1                       58    Andrzej Ankiersztejn
# 2                        5        Andrzej Biliński
# 3                       56              Rena Bieda
# 4                       35           Grażyna Blech
# ...                    ...                     ...
# 1748                    45            Janusz Piłat
# 1749                    55          Wiesław Wójcik
# 1750                    16              Ewa Powała
# 1751                    16         Sławomir Powała
# 1752                    11  Waldemar Rozmarynowski
#
# [1753 rows x 16 columns]

# %%
df_score_upd=df_score_upd.merge(df_scores[['PID','liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
       'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
       'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
       'liczba_rozdan_Wpadka', 'imię i nazwisko']],on='PID')

# %%
df_scores.columns
# Out:
# Index(['PID', 'średnia_na_rozgrywce', 'średnia_na_obronie',
#        'Kokosy_na_Obronie', 'częściówka', 'końcówka', 'szlemik', 'Wpadka',
#        'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
#        'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
#        'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
#        'liczba_rozdan_Wpadka', 'imię i nazwisko'],
#       dtype='object')

# %%
df_new['PID'] = df_new['PID']. astype (str)

# %%
df_players_to_merge=df_players[['PID','imię i nazwisko']]

# %%
df_scores['PID'] = df_scores['PID']. astype (str)

# %%
df_scores=df_scores.merge(df_players_to_merge,on='PID')

# %%
df_scores
# Out:
#         PID  średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  \
# 0     00567             37.117333           62.062857          85.875000
# 1     01001             45.473235           43.013966          69.920345
# 2     01005             59.463571           51.366667          71.047143
# 3     01010             41.141280           45.139484          68.710893
# 4     01056             49.885326           48.277805          71.384286
# ...     ...                   ...                 ...                ...
# 1748  21958             48.582109           44.546628          64.042712
# 1749  21959             48.255241           44.294511          63.222381
# 1750  21971             44.113200           40.312632          53.076154
# 1751  21972             44.113200           40.312632          53.076154
# 1752  22073             41.248438           41.605625          69.222667
#
#       częściówka   końcówka    szlemik     Wpadka  liczba_rozdan_na_rozgrywce  \
# 0      52.738333  36.740000  29.543333  23.327500                          15
# 1      45.582830  47.412157  48.971000  24.218103                         136
# 2      49.031538  67.100000  79.570000  37.476000                          14
# 3      42.232208  41.086782  39.425000  23.345357                         125
# 4      47.896615  46.401094  59.184444  26.110571                          92
# ...          ...        ...        ...        ...                         ...
# 1748   42.296145  48.502970  47.395833  24.975111                         128
# 1749   43.933736  48.609720  45.321538  25.014545                         145
# 1750   48.960625  39.956800  62.165000  22.347500                          50
# 1751   48.960625  39.956800  62.165000  22.347500                          50
# 1752   40.077273  30.445333  36.968333  25.240000                          32
#
#       liczba_rozdan_na_obronie  liczba_rozdan_Kokosy_na_Obronie  \
# 0                           14                                8
# 1                          116                               29
# 2                           15                                7
# 3                          155                               56
# 4                          123                               42
# ...                        ...                              ...
# 1748                       172                               59
# 1749                       184                               63
# 1750                        38                               13
# 1751                        38                               13
# 1752                        48                               15
#
#       liczba_rozdan_częściówka  liczba_rozdan_końcówka  liczba_rozdan_szlemik  \
# 0                            6                       4                      3
# 1                           53                     102                     10
# 2                           13                       3                      1
# 3                           77                      87                      4
# 4                           65                      64                      9
# ...                        ...                     ...                    ...
# 1748                        83                     101                     12
# 1749                        91                     107                     13
# 1750                        32                      25                      2
# 1751                        32                      25                      2
# 1752                        33                      15                      6
#
#       liczba_rozdan_Wpadka         imię i nazwisko
# 0                        8    Jarosław Kaczorowski
# 1                       58    Andrzej Ankiersztejn
# 2                        5        Andrzej Biliński
# 3                       56              Rena Bieda
# 4                       35           Grażyna Blech
# ...                    ...                     ...
# 1748                    45            Janusz Piłat
# 1749                    55          Wiesław Wójcik
# 1750                    16              Ewa Powała
# 1751                    16         Sławomir Powała
# 1752                    11  Waldemar Rozmarynowski
#
# [1753 rows x 16 columns]

# %%
min(df_new['średnia_na_rozgrywce'])
# Out:
# 36.72

# %%
df_stats # stara wersja df_scores
# Out:
#       Unnamed: 0    PID  średnia_na_rozgrywce  średnia_na_obronie  \
# 0              0    567             37.117333           62.062857
# 1              1   1001             45.473235           43.013966
# 2              2   1005             59.463571           51.366667
# 3              3   1010             41.141280           45.139484
# 4              4   1056             49.885326           48.277805
# ...          ...    ...                   ...                 ...
# 1748        1748  21958             48.582109           44.546628
# 1749        1749  21959             48.255241           44.294511
# 1750        1750  21971             44.113200           40.312632
# 1751        1751  21972             44.113200           40.312632
# 1752        1752  22073             41.248438           41.605625
#
#       Kokosy_na_Obronie  częściówka   końcówka    szlemik     Wpadka
# 0             85.875000   52.738333  36.740000  29.543333  23.327500
# 1             69.920345   45.582830  47.412157  48.971000  24.218103
# 2             71.047143   49.031538  67.100000  79.570000  37.476000
# 3             68.710893   42.232208  41.086782  39.425000  23.345357
# 4             71.384286   47.896615  46.401094  59.184444  26.110571
# ...                 ...         ...        ...        ...        ...
# 1748          64.042712   42.296145  48.502970  47.395833  24.975111
# 1749          63.222381   43.933736  48.609720  45.321538  25.014545
# 1750          53.076154   48.960625  39.956800  62.165000  22.347500
# 1751          53.076154   48.960625  39.956800  62.165000  22.347500
# 1752          69.222667   40.077273  30.445333  36.968333  25.240000
#
# [1753 rows x 9 columns]

# %%
df_players.to_csv('df_players.csv')
df_score_upd.to_csv('df_score_upd.csv')
df_all.to_csv('df_all.csv')

# %%
df_score_upd
# Out:
#         PID  średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  \
# 0     00567                  4.56               98.80              98.69
# 1     01001                 31.72               18.82              46.83
# 2     01005                 95.66               73.02              53.68
# 3     01010                 12.49               29.26              38.16
# 4     01056                 57.50               52.25              55.79
# ...     ...                   ...                 ...                ...
# 1748  21958                 49.12               26.07              16.60
# 1749  21959                 47.01               24.47              14.15
# 1750  21971                 23.96                9.53               1.65
# 1751  21972                 23.96                9.53               1.65
# 1752  22073                 12.78               13.63              41.53
#
#       częściówka  końcówka  szlemik  Wpadka  liczba_rozdan_na_rozgrywce  \
# 0          76.44      7.53    18.03   27.90                          15
# 1          33.94     46.49    54.31   32.80                         136
# 2          54.59     98.23    94.07   94.52                          14
# 3          17.40     16.83    35.65   28.07                         125
# 4          46.26     41.59    76.55   47.46                          92
# ...          ...       ...      ...     ...                         ...
# 1748       17.57     52.99    50.77   39.08                         128
# 1749       25.56     53.85    46.38   39.25                         145
# 1750       54.02     12.66    81.63   20.65                          50
# 1751       54.02     12.66    81.63   20.65                          50
# 1752       10.78      2.28    30.18   40.96                          32
#
#       liczba_rozdan_na_obronie  liczba_rozdan_Kokosy_na_Obronie  \
# 0                           14                                8
# 1                          116                               29
# 2                           15                                7
# 3                          155                               56
# 4                          123                               42
# ...                        ...                              ...
# 1748                       172                               59
# 1749                       184                               63
# 1750                        38                               13
# 1751                        38                               13
# 1752                        48                               15
#
#       liczba_rozdan_częściówka  liczba_rozdan_końcówka  liczba_rozdan_szlemik  \
# 0                            6                       4                      3
# 1                           53                     102                     10
# 2                           13                       3                      1
# 3                           77                      87                      4
# 4                           65                      64                      9
# ...                        ...                     ...                    ...
# 1748                        83                     101                     12
# 1749                        91                     107                     13
# 1750                        32                      25                      2
# 1751                        32                      25                      2
# 1752                        33                      15                      6
#
#       liczba_rozdan_Wpadka         imię i nazwisko
# 0                        8    Jarosław Kaczorowski
# 1                       58    Andrzej Ankiersztejn
# 2                        5        Andrzej Biliński
# 3                       56              Rena Bieda
# 4                       35           Grażyna Blech
# ...                    ...                     ...
# 1748                    45            Janusz Piłat
# 1749                    55          Wiesław Wójcik
# 1750                    16              Ewa Powała
# 1751                    16         Sławomir Powała
# 1752                    11  Waldemar Rozmarynowski
#
# [1753 rows x 16 columns]

# %%
df_all
# Out:
#         Unnamed: 0   id rozg  wynik  nr_rozdania  nr_turnieju  zapis linia  \
# 0                4    4   NS  26.77            3        25845  170.0    NS
# 1                5    4   NS  26.77            3        25845  170.0    NS
# 2                8    4   NS  63.39            8        25845  400.0    NS
# 3                9    4   NS  63.39            8        25845  400.0    NS
# 4               16    4   NS  51.98           18        25845  130.0    NS
# ...            ...  ...  ...    ...          ...          ...    ...   ...
# 273545      274570  244   EW  35.59           27        17666 -100.0    EW
# 273546      274597  382   EW  59.75           14        17666  -50.0    EW
# 273547      274598  382   EW  59.75           14        17666  -50.0    EW
# 273548      274623  382   EW  35.59           27        17666 -100.0    EW
# 273549      274624  382   EW  35.59           27        17666 -100.0    EW
#
#         m-ce   nr      %           nazwisko   wk    PID  czy_rozgrywa  \
# 0        371    4  46.28  Stefan Małowiecki  4.0   1482          True
# 1        371    4  46.28     Zbigniew Bobak  4.0   1247          True
# 2        371    4  46.28  Stefan Małowiecki  4.0   1482          True
# 3        371    4  46.28     Zbigniew Bobak  4.0   1247          True
# 4        371    4  46.28  Stefan Małowiecki  4.0   1482          True
# ...      ...  ...    ...                ...  ...    ...           ...
# 273545   286  244  51.96   Jerzy Jakubowski  1.5  18390          True
# 273546   142  382  56.07     Wojciech Wojsa  0.5  13918          True
# 273547   142  382  56.07  Michał Szadkowski  0.0  18841          True
# 273548   142  382  56.07     Wojciech Wojsa  0.5  13918          True
# 273549   142  382  56.07  Michał Szadkowski  0.0  18841          True
#
#             zapis2
# 0       częściówka
# 1       częściówka
# 2         końcówka
# 3         końcówka
# 4       częściówka
# ...            ...
# 273545      Wpadka
# 273546      Wpadka
# 273547      Wpadka
# 273548      Wpadka
# 273549      Wpadka
#
# [273550 rows x 16 columns]

# %%
df_players
# Out:
# 0        PID        imię i nazwisko WZBS  WK  TK      PKL liga  \
# 1      06706     Apolinary Kowalski   WM  24  AS  187 649    E
# 2      08513           Piotr Gawryś   DS  24  AS  149 944    E
# 3      06658           Jacek Kalita   SW  24  AS  146 928    E
# 4      01221         Cezary Balicki   DS  24  AS  143 379    -
# 5      04662      Michał Nowosadzki   SW  24  AS  137 689    E
# ...      ...                    ...  ...  ..  ..      ...  ...
# 13918  20956            Maciej Wisz   PK   0   D        1    -
# 13919  17464  Małgorzata Wiśniewska   DS   0   D        1    -
# 13920  20096       Adrian Witkowski   KP   0   D        1    -
# 13921  21716         Jakub Witowski   PK   0   D        1    -
# 13922  20387     Hanna Witruszyńska   DS   0   D        1    -
#
# 0                             klub / drużyna
# 1                          VITAS ESBS Elblag
# 2      BRIDGESCANNER KS AZS Wratislavia I WR
# 3                    SPS CONSTRUCTION Kielce
# 4                                        NaN
# 5                    SPS CONSTRUCTION Kielce
# ...                                      ...
# 13918                  Singleton Podkarpacki
# 13919                                    NaN
# 13920                                    NaN
# 13921                  Singleton Podkarpacki
# 13922                                    NaN
#
# [13922 rows x 8 columns]

# %% [markdown]
# ## Opis działań
# Do tej pory zostały stworzone 3 ramki danych: `df_players`, `df_score_upd`, `df_all`.
# - `df_players`: wszyscy gracze z PZBS-u, którzy zdobyli chociaż 1 pkt= zagrali w 1 turnieju. Zawiera unikatowe id(`PID`). Kolumna `WK` oznacza współczynnik klasyfikacyjny- im wyższy tym lepszy zawodnik.
# - `df_score_upd`: Stworzona na podstawie statystyk poszczególnych graczy z 20 zaciągniętych turniejów. Uwzględnia średnie wyniki z rozdań. Kolejne kolumny opisują średnie wyniki dla poszczególnych form gry- rozgrywka,obrona. Wszystkie statystyki oznaczają, w którym centylu znajduje się gracz (od ilu innych zawodników jest lepszy).
# - `df_all`: Wszystkie dane z 20 turniejów. Można wykorzystać do pobierania innych statystyk

# %% [markdown]
# ## Plan działań
# - Stworzenie dashboardu. Możemy wyszukać gracza po nazwisku lub numerze PID. Wyświetlane są statystyki gracza.
# - Dodanie możliwości przejrzenia wyników gracza z wybranego turnieju.
# - Na podstawie statystyk próba prognozy (% szans) na nagranie określonego wyniku.
# - Podejście pod Ml, mając wszystkie dane, czy zawodnik nagra wynik niski(<45%), średni(45%-60%) czy wysoki(>60%).

# %% [markdown]
# ## Próby pod ML- przygotowanie danych

# %%
df_all.columns
# Out:
# Index(['Unnamed: 0', 'id', 'rozg', 'wynik', 'nr_rozdania', 'nr_turnieju',
#        'zapis', 'linia', 'm-ce', 'nr', '%', 'nazwisko', 'wk', 'PID',
#        'czy_rozgrywa', 'zapis2'],
#       dtype='object')

# %%
tmp=df_all[['PID','%','nr_turnieju','nazwisko','wk']].drop_duplicates()

# %%
tmp
# Out:
#           PID      %  nr_turnieju               nazwisko   wk
# 0        1482  46.28        25845      Stefan Małowiecki  4.0
# 1        1247  46.28        25845         Zbigniew Bobak  4.0
# 20      21666  41.75        25845         Piotr Dimitriu  0.0
# 28      12964  43.35        25845  Konstanty Pawlikaniec  3.0
# 37       1633  58.00        25845     Grzegorz Skowronek  3.0
# ...       ...    ...          ...                    ...  ...
# 170934  19390  57.12        21728         Krzysztof Tuma  1.0
# 171140  14675  42.41        17693      Genowefa Sierocka  0.5
# 171141  11851  42.41        17693        Piotr Popławski  1.5
# 171446  21524  43.31        17666         Barbara Kasiak  0.0
# 171447  14675  43.31        17666      Genowefa Sierocka  0.5
#
# [9900 rows x 5 columns]

# %%
tmp['wynik_kategoria']=pd.cut(tmp['%'],bins=[0,50,100],labels=[0,1])

# %%
tmp['wynik_kategoria'].value_counts()
# Out:
# 0    4598
# 1    4359
# 2     943
# Name: wynik_kategoria, dtype: int64

# %%
tmp['PID']=tmp['PID']. astype (str)

# %%
tmp.columns
# Out:
# Index(['PID', '%', 'nr_turnieju', 'nazwisko', 'średnia_na_rozgrywce',
#        'średnia_na_obronie', 'Kokosy_na_Obronie', 'częściówka', 'końcówka',
#        'szlemik', 'Wpadka', 'liczba_rozdan_na_rozgrywce',
#        'liczba_rozdan_na_obronie', 'liczba_rozdan_Kokosy_na_Obronie',
#        'liczba_rozdan_częściówka', 'liczba_rozdan_końcówka',
#        'liczba_rozdan_szlemik', 'liczba_rozdan_Wpadka'],
#       dtype='object')

# %%
tmp=tmp.merge(df_score_upd[['PID', 'średnia_na_rozgrywce', 'średnia_na_obronie',
       'Kokosy_na_Obronie', 'częściówka', 'końcówka', 'szlemik', 'Wpadka',
       'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
       'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
       'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
       'liczba_rozdan_Wpadka']],on='PID')

# %%
tmp.columns
# Out:
# Index(['PID', '%', 'nr_turnieju', 'nazwisko', 'wynik_kategoria',
#        'średnia_na_rozgrywce', 'średnia_na_obronie', 'Kokosy_na_Obronie',
#        'częściówka', 'końcówka', 'szlemik', 'Wpadka',
#        'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
#        'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
#        'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
#        'liczba_rozdan_Wpadka'],
#       dtype='object')

# %%
df_ml_X=tmp[['średnia_na_rozgrywce', 'średnia_na_obronie', 'Kokosy_na_Obronie',
       'częściówka', 'końcówka', 'szlemik', 'Wpadka',
       'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
       'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
       'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
       'liczba_rozdan_Wpadka']]

# %%
df_ml_y=tmp['wynik_kategoria']

# %%
df_ml.to_csv('df_ml.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_ml_X, df_ml_y, test_size=0.2, random_state=42,stratify=df_ml_y)

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
# Requirement already satisfied: numpy in c:\users\p.okonek\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\p.okonek\anaconda3\lib\site-packages (from xgboost) (1.7.3)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.simplefilter('ignore')
import xgboost
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sn

# %%
model = XGBClassifier(max_depth=3, n_estimators=30)
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=30, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...)

# %%
model = XGBClassifier(max_depth=3, n_estimators=30)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=3, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=30, n_jobs=0,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, ...)

# %%
xgboost.plot_importance(model, max_num_features=7)
# Show the plot
plt.show()

# %%
y_pred = model.predict(X_test)
# Get the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71       649
#            1       0.57      0.66      0.61       593
#            2       0.51      0.13      0.21       138
#
#     accuracy                           0.63      1380
#    macro avg       0.60      0.50      0.51      1380
# weighted avg       0.63      0.63      0.62      1380

# %%
array = confusion_matrix(y_test, y_pred)
df = pd.DataFrame(array, index=['0', '1','2'], columns=[
'0','1','2'])
plt.figure(figsize=(5, 4))
sn.heatmap(df, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
kfold = KFold(n_splits=3)
# Perform K-Fold Cross Validation
results = cross_val_score(model, X_test, y_test, cv=kfold)
# Print the average results
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Accuracy: 60.07% (0.98%)

# %% [markdown]
# ## Wnioski:
# - tragiczny wynik dla kategorii 57+
# - Niezły wynik dla <50
# - Trzeba dołożyć WK może poziom ligi
# - Sprawdzić co dla problemu: czy nagramy średnią (binarny problem)
# - Hiperparametry
#
# ---------------------------
# - co od strony statystyki?
# * przedziały ufności, p_value- czy zawodnik wygra (na podstawie poprzednich wyników)

# %% [markdown]
# ## Czy zawodnik nagra średnią?

# %%
df_ml=pd.read_csv('df_ml.csv')
df_all=pd.read_csv('df_all.csv')
df_players=pd.read_csv('df_players.csv')
df_score_upd=pd.read_csv('df_score_upd.csv')

# %%
tmp['wynik_kategoria']=pd.cut(tmp['%'],bins=[0,50,100],labels=[0,1])

# %%
tmp['wynik_kategoria'].value_counts()
# Out:
# 0    4121
# 1    2779
# Name: wynik_kategoria, dtype: int64

# %%
tmp['PID']=tmp['PID']. astype (str)

# %%
tmp
# Out:
#         PID      %  nr_turnieju            nazwisko   wk  \
# 0     01482  46.28        25845   Stefan Małowiecki  4.0
# 1     01482  52.52        25809   Stefan Małowiecki  4.0
# 2     01482  58.42        25773   Stefan Małowiecki  4.0
# 3     01482  42.88        25737   Stefan Małowiecki  4.0
# 4     01482  49.79        25692   Stefan Małowiecki  4.0
# ...     ...    ...          ...                 ...  ...
# 9541  18367  53.76        25773      Bożena Listwoń  2.0
# 9542  18367  52.19        24303      Bożena Listwoń  2.0
# 9543  18367  43.31        17666      Bożena Listwoń  1.5
# 9544  10504  48.76        17666   Andrzej Sontowski  3.0
# 9545  09929  48.76        17666  Waldemar Stępiński  2.5
#
#       średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  częściówka  \
# 0                    47.40               77.87              83.51       56.53
# 1                    47.40               77.87              83.51       56.53
# 2                    47.40               77.87              83.51       56.53
# 3                    47.40               77.87              83.51       56.53
# 4                    47.40               77.87              83.51       56.53
# ...                    ...                 ...                ...         ...
# 9541                 26.70               60.58              42.44        1.88
# 9542                 26.70               60.58              42.44        1.88
# 9543                 26.70               60.58              42.44        1.88
# 9544                 41.41               57.79              60.18       61.78
# 9545                 41.41               57.79              60.18       61.78
#
#       końcówka  szlemik  Wpadka  liczba_rozdan_na_rozgrywce  \
# 0        85.97    69.65   36.39                         255
# 1        85.97    69.65   36.39                         255
# 2        85.97    69.65   36.39                         255
# 3        85.97    69.65   36.39                         255
# 4        85.97    69.65   36.39                         255
# ...        ...      ...     ...                         ...
# 9541      4.22     7.59   24.53                          13
# 9542      4.22     7.59   24.53                          13
# 9543      4.22     7.59   24.53                          13
# 9544     47.40    90.93   43.18                          16
# 9545     47.40    90.93   43.18                          16
#
#       liczba_rozdan_na_obronie  liczba_rozdan_Kokosy_na_Obronie  \
# 0                          204                               77
# 1                          204                               77
# 2                          204                               77
# 3                          204                               77
# 4                          204                               77
# ...                        ...                              ...
# 9541                       140                               69
# 9542                       140                               69
# 9543                       140                               69
# 9544                        13                                5
# 9545                        13                                5
#
#       liczba_rozdan_częściówka  liczba_rozdan_końcówka  liczba_rozdan_szlemik  \
# 0                          121                     131                     24
# 1                          121                     131                     24
# 2                          121                     131                     24
# 3                          121                     131                     24
# 4                          121                     131                     24
# ...                        ...                     ...                    ...
# 9541                        35                      38                      4
# 9542                        35                      38                      4
# 9543                        35                      38                      4
# 9544                         7                       7                      2
# 9545                         7                       7                      2
#
#       liczba_rozdan_Wpadka wynik_kategoria
# 0                      106               0
# 1                      106               1
# 2                      106               1
# 3                      106               0
# 4                      106               0
# ...                    ...             ...
# 9541                     7               1
# 9542                     7               1
# 9543                     7               0
# 9544                     8               0
# 9545                     8               0
#
# [9546 rows x 20 columns]

# %%
tmp['PID'].iloc[0].rjust(5,'0')
# Out:
# '01482'

# %%
df_all['wk']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         4.0
# 4         4.0
#          ...
# 273545    1.5
# 273546    0.5
# 273547    0.0
# 273548    0.5
# 273549    0.0
# Name: wk, Length: 273550, dtype: float64

# %%
tmp['PID']=tmp['PID']. astype (str)
for i in range(len(tmp['PID'])):
    tmp['PID'].iloc[i]=tmp['PID'].iloc[i].rjust(5,'0')
tmp
# Out:
#           PID      %  nr_turnieju               nazwisko   wk
# 0       01482  46.28        25845      Stefan Małowiecki  4.0
# 1       01247  46.28        25845         Zbigniew Bobak  4.0
# 20      21666  41.75        25845         Piotr Dimitriu  0.0
# 28      12964  43.35        25845  Konstanty Pawlikaniec  3.0
# 37      01633  58.00        25845     Grzegorz Skowronek  3.0
# ...       ...    ...          ...                    ...  ...
# 170934  19390  57.12        21728         Krzysztof Tuma  1.0
# 171140  14675  42.41        17693      Genowefa Sierocka  0.5
# 171141  11851  42.41        17693        Piotr Popławski  1.5
# 171446  21524  43.31        17666         Barbara Kasiak  0.0
# 171447  14675  43.31        17666      Genowefa Sierocka  0.5
#
# [9900 rows x 5 columns]

# %%
tmp=tmp.merge(df_players[['PID','WK']],on='PID')

# %%
df_score_upd['PID'].iloc[i]
# Out:
# 567

# %%
df_score_upd
# Out:
#       Unnamed: 0    PID  średnia_na_rozgrywce  średnia_na_obronie  \
# 0              0  00567                  4.56               98.80
# 1              1  01001                 31.72               18.82
# 2              2  01005                 95.66               73.02
# 3              3  01010                 12.49               29.26
# 4              4  01056                 57.50               52.25
# ...          ...    ...                   ...                 ...
# 1748        1748  21958                 49.12               26.07
# 1749        1749  21959                 47.01               24.47
# 1750        1750  21971                 23.96                9.53
# 1751        1751  21972                 23.96                9.53
# 1752        1752  22073                 12.78               13.63
#
#       Kokosy_na_Obronie  częściówka  końcówka  szlemik  Wpadka  \
# 0                 98.69       76.44      7.53    18.03   27.90
# 1                 46.83       33.94     46.49    54.31   32.80
# 2                 53.68       54.59     98.23    94.07   94.52
# 3                 38.16       17.40     16.83    35.65   28.07
# 4                 55.79       46.26     41.59    76.55   47.46
# ...                 ...         ...       ...      ...     ...
# 1748              16.60       17.57     52.99    50.77   39.08
# 1749              14.15       25.56     53.85    46.38   39.25
# 1750               1.65       54.02     12.66    81.63   20.65
# 1751               1.65       54.02     12.66    81.63   20.65
# 1752              41.53       10.78      2.28    30.18   40.96
#
#       liczba_rozdan_na_rozgrywce  liczba_rozdan_na_obronie  \
# 0                             15                        14
# 1                            136                       116
# 2                             14                        15
# 3                            125                       155
# 4                             92                       123
# ...                          ...                       ...
# 1748                         128                       172
# 1749                         145                       184
# 1750                          50                        38
# 1751                          50                        38
# 1752                          32                        48
#
#       liczba_rozdan_Kokosy_na_Obronie  liczba_rozdan_częściówka  \
# 0                                   8                         6
# 1                                  29                        53
# 2                                   7                        13
# 3                                  56                        77
# 4                                  42                        65
# ...                               ...                       ...
# 1748                               59                        83
# 1749                               63                        91
# 1750                               13                        32
# 1751                               13                        32
# 1752                               15                        33
#
#       liczba_rozdan_końcówka  liczba_rozdan_szlemik  liczba_rozdan_Wpadka  \
# 0                          4                      3                     8
# 1                        102                     10                    58
# 2                          3                      1                     5
# 3                         87                      4                    56
# 4                         64                      9                    35
# ...                      ...                    ...                   ...
# 1748                     101                     12                    45
# 1749                     107                     13                    55
# 1750                      25                      2                    16
# 1751                      25                      2                    16
# 1752                      15                      6                    11
#
#              imię i nazwisko
# 0       Jarosław Kaczorowski
# 1       Andrzej Ankiersztejn
# 2           Andrzej Biliński
# 3                 Rena Bieda
# 4              Grażyna Blech
# ...                      ...
# 1748            Janusz Piłat
# 1749          Wiesław Wójcik
# 1750              Ewa Powała
# 1751         Sławomir Powała
# 1752  Waldemar Rozmarynowski
#
# [1753 rows x 17 columns]

# %%
df_score_upd['PID']=df_score_upd['PID']. astype (str)
for i in range(len(df_score_upd['PID'])):
    df_score_upd['PID'].iloc[i]=df_score_upd['PID'].iloc[i].rjust(5,'0')
df_score_upd

# %%
tmp=tmp.merge(df_score_upd[['PID', 'średnia_na_rozgrywce', 'średnia_na_obronie',
       'Kokosy_na_Obronie', 'częściówka', 'końcówka', 'szlemik', 'Wpadka',
       'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
       'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
       'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
       'liczba_rozdan_Wpadka']],on='PID')

# %%
tmp
# Out:
#         PID      %  nr_turnieju            nazwisko   WK  \
# 0     01482  46.28        25845   Stefan Małowiecki    4
# 1     01482  52.52        25809   Stefan Małowiecki    4
# 2     01482  58.42        25773   Stefan Małowiecki    4
# 3     01482  42.88        25737   Stefan Małowiecki    4
# 4     01482  49.79        25692   Stefan Małowiecki    4
# ...     ...    ...          ...                 ...  ...
# 9541  18367  53.76        25773      Bożena Listwoń    2
# 9542  18367  52.19        24303      Bożena Listwoń    2
# 9543  18367  43.31        17666      Bożena Listwoń    2
# 9544  10504  48.76        17666   Andrzej Sontowski    3
# 9545  09929  48.76        17666  Waldemar Stępiński  2.5
#
#       średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  częściówka  \
# 0                    47.40               77.87              83.51       56.53
# 1                    47.40               77.87              83.51       56.53
# 2                    47.40               77.87              83.51       56.53
# 3                    47.40               77.87              83.51       56.53
# 4                    47.40               77.87              83.51       56.53
# ...                    ...                 ...                ...         ...
# 9541                 26.70               60.58              42.44        1.88
# 9542                 26.70               60.58              42.44        1.88
# 9543                 26.70               60.58              42.44        1.88
# 9544                 41.41               57.79              60.18       61.78
# 9545                 41.41               57.79              60.18       61.78
#
#       końcówka  szlemik  Wpadka  liczba_rozdan_na_rozgrywce  \
# 0        85.97    69.65   36.39                         255
# 1        85.97    69.65   36.39                         255
# 2        85.97    69.65   36.39                         255
# 3        85.97    69.65   36.39                         255
# 4        85.97    69.65   36.39                         255
# ...        ...      ...     ...                         ...
# 9541      4.22     7.59   24.53                          13
# 9542      4.22     7.59   24.53                          13
# 9543      4.22     7.59   24.53                          13
# 9544     47.40    90.93   43.18                          16
# 9545     47.40    90.93   43.18                          16
#
#       liczba_rozdan_na_obronie  liczba_rozdan_Kokosy_na_Obronie  \
# 0                          204                               77
# 1                          204                               77
# 2                          204                               77
# 3                          204                               77
# 4                          204                               77
# ...                        ...                              ...
# 9541                       140                               69
# 9542                       140                               69
# 9543                       140                               69
# 9544                        13                                5
# 9545                        13                                5
#
#       liczba_rozdan_częściówka  liczba_rozdan_końcówka  liczba_rozdan_szlemik  \
# 0                          121                     131                     24
# 1                          121                     131                     24
# 2                          121                     131                     24
# 3                          121                     131                     24
# 4                          121                     131                     24
# ...                        ...                     ...                    ...
# 9541                        35                      38                      4
# 9542                        35                      38                      4
# 9543                        35                      38                      4
# 9544                         7                       7                      2
# 9545                         7                       7                      2
#
#       liczba_rozdan_Wpadka
# 0                      106
# 1                      106
# 2                      106
# 3                      106
# 4                      106
# ...                    ...
# 9541                     7
# 9542                     7
# 9543                     7
# 9544                     8
# 9545                     8
#
# [9546 rows x 19 columns]

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9546 entries, 0 to 9545
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PID                              9546 non-null   object
#  1   %                                9546 non-null   float64
#  2   nr_turnieju                      9546 non-null   int64
#  3   nazwisko                         9546 non-null   object
#  4   wk                               9546 non-null   float64
#  5   średnia_na_rozgrywce             9546 non-null   float64
#  6   średnia_na_obronie               9546 non-null   float64
#  7   Kokosy_na_Obronie                9546 non-null   float64
#  8   częściówka                       9546 non-null   float64
#  9   końcówka                         9546 non-null   float64
#  10  szlemik                          9546 non-null   float64
#  11  Wpadka                           9546 non-null   float64
#  12  liczba_rozdan_na_rozgrywce       9546 non-null   int64
#  13  liczba_rozdan_na_obronie         9546 non-null   int64
#  14  liczba_rozdan_Kokosy_na_Obronie  9546 non-null   int64
#  15  liczba_rozdan_częściówka         9546 non-null   int64
#  16  liczba_rozdan_końcówka           9546 non-null   int64
#  17  liczba_rozdan_szlemik            9546 non-null   int64
#  18  liczba_rozdan_Wpadka             9546 non-null   int64
#  19  wynik_kategoria                  9546 non-null   category
# dtypes: category(1), float64(9), int64(8), object(2)
# memory usage: 1.5+ MB

# %%
df_ml_y=tmp['wynik_kategoria']

# %%
df_ml_X=tmp[['średnia_na_rozgrywce', 'średnia_na_obronie', 'Kokosy_na_Obronie',
       'częściówka', 'końcówka', 'szlemik', 'Wpadka',
       'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
       'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
       'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
       'liczba_rozdan_Wpadka','wk']]

X_train, X_test, y_train, y_test = train_test_split(df_ml_X, df_ml_y, test_size=0.2, random_state=42,stratify=df_ml_y)

# %%
import numpy as np

# %%
xgb_model = xgboost.XGBClassifier(eta=0.1, nrounds=1000, max_depth=2, colsample_bytree=0.5, scale_pos_weight=1.1, booster='gbtree', 
                                  metric='multi:softmax')
hr_pred = xgb_model.fit(X_train._get_numeric_data(), np.ravel(y_train, order='C')).predict(X_test._get_numeric_data())
print(classification_report(y_test, hr_pred))
# Out:
# [15:02:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "metric", "nrounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77      1130
#            1       0.67      0.65      0.66       780
#
#     accuracy                           0.73      1910
#    macro avg       0.72      0.71      0.72      1910
# weighted avg       0.73      0.73      0.73      1910

# %%
xgb_model = xgboost.XGBClassifier(eta=0.1, nrounds=1000, max_depth=2, colsample_bytree=0.5, scale_pos_weight=1.1, booster='gbtree', metric='multi:softmax')
hr_pred = xgb_model.fit(X_train._get_numeric_data(), np.ravel(y_train, order='C')).predict(X_test._get_numeric_data())
# Out:
# [11:54:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "metric", "nrounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
print(classification_report(y_test, hr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77      1130
#            1       0.67      0.65      0.66       780
#
#     accuracy                           0.73      1910
#    macro avg       0.72      0.71      0.71      1910
# weighted avg       0.72      0.73      0.73      1910

# %%
array = confusion_matrix(y_test, hr_pred)
df = pd.DataFrame(array, index=['0', '1'], columns=[
'0','1'])
plt.figure(figsize=(5, 4))
sn.heatmap(df, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
xgboost.plot_importance(xgb_model, max_num_features=20)
# Show the plot
plt.show()

# %% [markdown]
# ## Wnioski
# - Problem jest możliwy do rozwiązania
# - Można skategoryzować dane po WOE
# - Dodatkowo kilka histogramów (liczba rozdań)
# - na koniec przejechać po hiperparametrach

# %%
tmp
# Out:
#         PID      %  nr_turnieju            nazwisko   wk  \
# 0     01482  46.28        25845   Stefan Małowiecki  4.0
# 1     01482  52.52        25809   Stefan Małowiecki  4.0
# 2     01482  58.42        25773   Stefan Małowiecki  4.0
# 3     01482  42.88        25737   Stefan Małowiecki  4.0
# 4     01482  49.79        25692   Stefan Małowiecki  4.0
# ...     ...    ...          ...                 ...  ...
# 9541  18367  53.76        25773      Bożena Listwoń  2.0
# 9542  18367  52.19        24303      Bożena Listwoń  2.0
# 9543  18367  43.31        17666      Bożena Listwoń  1.5
# 9544  10504  48.76        17666   Andrzej Sontowski  3.0
# 9545  09929  48.76        17666  Waldemar Stępiński  2.5
#
#       średnia_na_rozgrywce  średnia_na_obronie  Kokosy_na_Obronie  częściówka  \
# 0                    47.40               77.87              83.51       56.53
# 1                    47.40               77.87              83.51       56.53
# 2                    47.40               77.87              83.51       56.53
# 3                    47.40               77.87              83.51       56.53
# 4                    47.40               77.87              83.51       56.53
# ...                    ...                 ...                ...         ...
# 9541                 26.70               60.58              42.44        1.88
# 9542                 26.70               60.58              42.44        1.88
# 9543                 26.70               60.58              42.44        1.88
# 9544                 41.41               57.79              60.18       61.78
# 9545                 41.41               57.79              60.18       61.78
#
#       końcówka  szlemik  Wpadka  liczba_rozdan_na_rozgrywce  \
# 0        85.97    69.65   36.39                         255
# 1        85.97    69.65   36.39                         255
# 2        85.97    69.65   36.39                         255
# 3        85.97    69.65   36.39                         255
# 4        85.97    69.65   36.39                         255
# ...        ...      ...     ...                         ...
# 9541      4.22     7.59   24.53                          13
# 9542      4.22     7.59   24.53                          13
# 9543      4.22     7.59   24.53                          13
# 9544     47.40    90.93   43.18                          16
# 9545     47.40    90.93   43.18                          16
#
#       liczba_rozdan_na_obronie  liczba_rozdan_Kokosy_na_Obronie  \
# 0                          204                               77
# 1                          204                               77
# 2                          204                               77
# 3                          204                               77
# 4                          204                               77
# ...                        ...                              ...
# 9541                       140                               69
# 9542                       140                               69
# 9543                       140                               69
# 9544                        13                                5
# 9545                        13                                5
#
#       liczba_rozdan_częściówka  liczba_rozdan_końcówka  liczba_rozdan_szlemik  \
# 0                          121                     131                     24
# 1                          121                     131                     24
# 2                          121                     131                     24
# 3                          121                     131                     24
# 4                          121                     131                     24
# ...                        ...                     ...                    ...
# 9541                        35                      38                      4
# 9542                        35                      38                      4
# 9543                        35                      38                      4
# 9544                         7                       7                      2
# 9545                         7                       7                      2
#
#       liczba_rozdan_Wpadka wynik_kategoria
# 0                      106               0
# 1                      106               1
# 2                      106               1
# 3                      106               0
# 4                      106               0
# ...                    ...             ...
# 9541                     7               1
# 9542                     7               1
# 9543                     7               0
# 9544                     8               0
# 9545                     8               0
#
# [9546 rows x 20 columns]

# %%
zz=tmp.groupby(['PID'])['liczba_rozdan_Wpadka'].mean()
plt.hist(zz)
# Out:
# (array([619., 408., 277., 162., 143.,  75.,  48.,  15.,   3.,   3.]),
#  array([  1. ,  13.5,  26. ,  38.5,  51. ,  63.5,  76. ,  88.5, 101. ,
#         113.5, 126. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - Liczba rozdan rozgrywka: 0-50 50-140 140+
# - liczba_rozdan_na_obronie: 0-110 110+
# - liczba_rozdan_Kokosy_na_Obronie: 0-30 30+
# - liczba_rozdan_częściówka: 0-40 40-90 90+
# - liczba_rozdan_końcówka: 0-50 50+
# - liczba_rozdan_szlemik: 0-5 5-10 10+
# - liczba_rozdan_Wpadka: 0-30 30-60 60+

# %%
plt.hist(tmp['%'])
# Out:
# (array([   6.,   69.,  471., 1429., 2538., 2789., 1605.,  535.,   96.,
#            8.]),
#  array([23.15 , 28.156, 33.162, 38.168, 43.174, 48.18 , 53.186, 58.192,
#         63.198, 68.204, 73.21 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Wyniki są prawie idealnie normalne. Warto pomyśleć o metodach statystycznych!.

# %%
df_ml.columns
# Out:
# Index(['średnia_na_rozgrywce', 'średnia_na_obronie', 'Kokosy_na_Obronie',
#        'częściówka', 'końcówka', 'szlemik', 'Wpadka',
#        'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
#        'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
#        'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
#        'liczba_rozdan_Wpadka'],
#       dtype='object')

# %%
plt.hist(zz)
# Out:
# (array([540., 411., 261., 162., 142.,  96.,  74.,  45.,  18.,   4.]),
#  array([  3. ,  31.4,  59.8,  88.2, 116.6, 145. , 173.4, 201.8, 230.2,
#         258.6, 287. ]),
#  <BarContainer object of 10 artists>)

# %%
for c in df_ml.columns:
    df_ml_X[c+'cat']=pd.cut(df_ml_X[c], bins=5, right=True,labels=[0,1,2,3,4])

# %%
df_ml_X.columns
# Out:
# Index(['średnia_na_rozgrywce', 'średnia_na_obronie', 'Kokosy_na_Obronie',
#        'częściówka', 'końcówka', 'szlemik', 'Wpadka',
#        'liczba_rozdan_na_rozgrywce', 'liczba_rozdan_na_obronie',
#        'liczba_rozdan_Kokosy_na_Obronie', 'liczba_rozdan_częściówka',
#        'liczba_rozdan_końcówka', 'liczba_rozdan_szlemik',
#        'liczba_rozdan_Wpadka', 'wk', 'średnia_na_rozgrywcecat',
#        'średnia_na_obroniecat', 'Kokosy_na_Obroniecat', 'częściówkacat',
#        'końcówkacat', 'szlemikcat', 'Wpadkacat',
#        'liczba_rozdan_na_rozgrywcecat', 'liczba_rozdan_na_obroniecat',
#        'liczba_rozdan_Kokosy_na_Obroniecat', 'liczba_rozdan_częściówkacat',
#        'liczba_rozdan_końcówkacat', 'liczba_rozdan_szlemikcat',
#        'liczba_rozdan_Wpadkacat'],
#       dtype='object')

# %%
df_cat=df_ml_X[['wk', 'średnia_na_rozgrywcecat',
       'średnia_na_obroniecat', 'Kokosy_na_Obroniecat', 'częściówkacat',
       'końcówkacat', 'szlemikcat', 'Wpadkacat',
       'liczba_rozdan_na_rozgrywcecat', 'liczba_rozdan_na_obroniecat',
       'liczba_rozdan_Kokosy_na_Obroniecat', 'liczba_rozdan_częściówkacat',
       'liczba_rozdan_końcówkacat', 'liczba_rozdan_szlemikcat',
       'liczba_rozdan_Wpadkacat']]

# %%
df_cat
# Out:
#        wk średnia_na_rozgrywcecat średnia_na_obroniecat Kokosy_na_Obroniecat  \
# 0     4.0                       2                     3                    4
# 1     4.0                       2                     3                    4
# 2     4.0                       2                     3                    4
# 3     4.0                       2                     3                    4
# 4     4.0                       2                     3                    4
# ...   ...                     ...                   ...                  ...
# 9541  2.0                       1                     3                    2
# 9542  2.0                       1                     3                    2
# 9543  1.5                       1                     3                    2
# 9544  3.0                       2                     2                    3
# 9545  2.5                       2                     2                    3
#
#      częściówkacat końcówkacat szlemikcat Wpadkacat  \
# 0                2           4          3         1
# 1                2           4          3         1
# 2                2           4          3         1
# 3                2           4          3         1
# 4                2           4          3         1
# ...            ...         ...        ...       ...
# 9541             0           0          0         1
# 9542             0           0          0         1
# 9543             0           0          0         1
# 9544             3           2          4         2
# 9545             3           2          4         2
#
#      liczba_rozdan_na_rozgrywcecat liczba_rozdan_na_obroniecat  \
# 0                                4                           2
# 1                                4                           2
# 2                                4                           2
# 3                                4                           2
# 4                                4                           2
# ...                            ...                         ...
# 9541                             0                           1
# 9542                             0                           1
# 9543                             0                           1
# 9544                             0                           0
# 9545                             0                           0
#
#      liczba_rozdan_Kokosy_na_Obroniecat liczba_rozdan_częściówkacat  \
# 0                                     2                           3
# 1                                     2                           3
# 2                                     2                           3
# 3                                     2                           3
# 4                                     2                           3
# ...                                 ...                         ...
# 9541                                  1                           1
# 9542                                  1                           1
# 9543                                  1                           1
# 9544                                  0                           0
# 9545                                  0                           0
#
#      liczba_rozdan_końcówkacat liczba_rozdan_szlemikcat  \
# 0                            3                        4
# 1                            3                        4
# 2                            3                        4
# 3                            3                        4
# 4                            3                        4
# ...                        ...                      ...
# 9541                         1                        0
# 9542                         1                        0
# 9543                         1                        0
# 9544                         0                        0
# 9545                         0                        0
#
#      liczba_rozdan_Wpadkacat
# 0                          4
# 1                          4
# 2                          4
# 3                          4
# 4                          4
# ...                      ...
# 9541                       0
# 9542                       0
# 9543                       0
# 9544                       0
# 9545                       0
#
# [9546 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_cat, df_ml_y, test_size=0.2, random_state=42,stratify=df_ml_y)

# %%
X_train['średnia_na_rozgrywcecat']=X_train['średnia_na_rozgrywcecat'].astype(int)

# %%
for c in X_train.columns:
    X_train[c]=X_train[c].astype(float)
    X_test[c]=X_test[c].astype(float)

# %%
model = XGBClassifier(max_depth=2, n_estimators=30)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=30, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred = model.predict(X_test)
# Get the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78      1130
#            1       0.69      0.58      0.63       780
#
#     accuracy                           0.72      1910
#    macro avg       0.71      0.70      0.70      1910
# weighted avg       0.72      0.72      0.72      1910

# %%
array = confusion_matrix(y_test, y_pred)
df = pd.DataFrame(array, index=['0', '1'], columns=[
'0','1'])
plt.figure(figsize=(5, 4))
sn.heatmap(df, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
df_cat.to_csv('df_cat.csv')

# %%
tmp.to_csv('tmp.csv')

# %% [markdown]
# Pogrupowanie na 5 kategorii utrzymało dokładność. Wysoki recall na grupie `0`. Błędy przy wyznaczaniu 1.

# %% [markdown]
# ### Wniosek:
# - model kategoryczny dobry do słabych graczy
# - model ciągły porównywalnie dla obu klas

# %%
df_all=pd.read_csv('df_all.csv',index_col=False)

# %%
df_all=df_all.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1)

# %%
df_all
# Out:
#          id rozg  wynik  nr_rozdania  nr_turnieju  zapis linia  m-ce   nr  \
# 0         4   NS  26.77            3        25845  170.0    NS   371    4
# 1         4   NS  26.77            3        25845  170.0    NS   371    4
# 2         4   NS  63.39            8        25845  400.0    NS   371    4
# 3         4   NS  63.39            8        25845  400.0    NS   371    4
# 4         4   NS  51.98           18        25845  130.0    NS   371    4
# ...     ...  ...    ...          ...          ...    ...   ...   ...  ...
# 273545  244   EW  35.59           27        17666 -100.0    EW   286  244
# 273546  382   EW  59.75           14        17666  -50.0    EW   142  382
# 273547  382   EW  59.75           14        17666  -50.0    EW   142  382
# 273548  382   EW  35.59           27        17666 -100.0    EW   142  382
# 273549  382   EW  35.59           27        17666 -100.0    EW   142  382
#
#             %           nazwisko   wk    PID  czy_rozgrywa      zapis2
# 0       46.28  Stefan Małowiecki  4.0   1482          True  częściówka
# 1       46.28     Zbigniew Bobak  4.0   1247          True  częściówka
# 2       46.28  Stefan Małowiecki  4.0   1482          True    końcówka
# 3       46.28     Zbigniew Bobak  4.0   1247          True    końcówka
# 4       46.28  Stefan Małowiecki  4.0   1482          True  częściówka
# ...       ...                ...  ...    ...           ...         ...
# 273545  51.96   Jerzy Jakubowski  1.5  18390          True      Wpadka
# 273546  56.07     Wojciech Wojsa  0.5  13918          True      Wpadka
# 273547  56.07  Michał Szadkowski  0.0  18841          True      Wpadka
# 273548  56.07     Wojciech Wojsa  0.5  13918          True      Wpadka
# 273549  56.07  Michał Szadkowski  0.0  18841          True      Wpadka
#
# [273550 rows x 15 columns]

# %%
vector=df_all['PID'].unique()

# %%
zzz=pd.DataFrame({'PID'})

# %%
import numpy as np

# %%
df=pd.DataFrame(index=np.arange(1), columns=np.arange(21))

# %%
df.columns=['PID',25890,25845,25809,25773,25737,25692,24384,24339,24303,24267,24222,24186,24150,22079 ,22043 ,21800,21764,21728,17693,17666]

# %%
z=0
for v in vector:
    tmp=df_all[df_all['PID']==i][['PID','%','nr_turnieju']].drop_duplicates()
    df['PID'][i]=v
    df2=pd.DataFrame(index=np.arange(1), columns=np.arange(2))
    for j in range(20):
        df2.loc[j,0]=tab[j]
    df2=df2.rename({0:'nr_turnieju'},axis=1)
    df2=df2.merge(tmp,on='nr_turnieju',how='left')
    for k in range(20):
        df.loc[z,k+1]=
    z=z+1

# %%
df
# Out:
#    PID 25890 25845 25809 25773 25737 25692 24384 24339 24303  ... 24222 24186  \
# 0  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
#
#   24150 22079 22043 21800 21764 21728 17693 17666
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 21 columns]

# %%
tab=[25890,25845,25809,25773,25737,25692,24384,24339,24303,24267,24222,24186,24150,22079 ,22043 ,21800,21764,21728,17693,17666]

# %%
df.iloc[0]=[25890,25845,25809,25773,25737,25692,24384,24339,24303,24267,24222,24186,24150,22079 ,22043 ,21800,21764,21728,17693,17666]

# %%
df2=pd.DataFrame(index=np.arange(1), columns=np.arange(2))

# %%
df2=df2.rename({0:'nr_turnieju'},axis=1)

# %%
for i in range(20):
    df2.loc[i,0]=tab[i]

# %%
df2=df2.merge(tmp,on='nr_turnieju',how='left')

# %%
df2=df2.drop(1,axis=1)

# %%
df2['PID']=1482

# %%
df2
# Out:
#    nr_turnieju   PID      %
# 0        25890  1482    NaN
# 1        25845  1482  46.28
# 2        25809  1482  52.52
# 3        25773  1482  58.42
# 4        25737  1482  42.88
# 5        25692  1482  49.79
# 6        24384  1482  40.31
# 7        24339  1482  55.94
# 8        24303  1482  44.66
# 9        24267  1482    NaN
# 10       24222  1482  60.26
# 11       24186  1482  50.88
# 12       24150  1482  50.60
# 13       22079  1482  46.03
# 14       22043  1482  49.03
# 15       21800  1482  45.44
# 16       21764  1482    NaN
# 17       21728  1482  42.45
# 18       17693  1482  51.10
# 19       17666  1482  58.47

# %%
for v in vector:
# Out:
#         PID      %  nr_turnieju
# 0      1482  46.28        25845
# 4455   1482  52.52        25809
# 11307  1482  58.42        25773
# 17203  1482  42.88        25737
# 17698  1482  49.79        25692
# 24848  1482  40.31        24384
# 25237  1482  55.94        24339
# 33395  1482  44.66        24303
# 37853  1482  60.26        24222
# 40847  1482  50.88        24186
# 43514  1482  50.60        24150
# 43813  1482  46.03        22079
# 45281  1482  49.03        22043
# 51537  1482  45.44        21800
# 64600  1482  42.45        21728
# 64710  1482  51.10        17693
# 70362  1482  58.47        17666

# %%
tmp=df_all[df_all['PID']==1482][['PID','%','nr_turnieju']].drop_duplicates()
# Out:
#         PID      %  nr_turnieju
# 0      1482  46.28        25845
# 4455   1482  52.52        25809
# 11307  1482  58.42        25773
# 17203  1482  42.88        25737
# 17698  1482  49.79        25692
# 24848  1482  40.31        24384
# 25237  1482  55.94        24339
# 33395  1482  44.66        24303
# 37853  1482  60.26        24222
# 40847  1482  50.88        24186
# 43514  1482  50.60        24150
# 43813  1482  46.03        22079
# 45281  1482  49.03        22043
# 51537  1482  45.44        21800
# 64600  1482  42.45        21728
# 64710  1482  51.10        17693
# 70362  1482  58.47        17666
